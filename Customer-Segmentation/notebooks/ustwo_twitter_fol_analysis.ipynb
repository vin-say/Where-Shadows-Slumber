# %% [markdown]
# # Targeted advertising with mined Twitter data
# Vincent Sayseng (last update: January 3, 2020)
#
# ## Table of contents
#
# 1. [Motivation](#motivation)
# 2. [Clustering methods and results](#methodsresults)
#     1. [Data exploration](#explore)
#     2. [Text wrangling of profile descriptions](#wrangle)
#     3. [Clustering users based on their profile descriptions](#clustering)
#         1. [K-modes clustering](#kmodes)
#         2. [DBSCAN clustering](#dbscan)
#     4. [Clustering users based on their friends](#friendcluster)
# 3. [Business strategy recommendations](#strategy)
#     1. [Recommendations for Facebook ads](#fb)
#     2. [Recommendations for Twitter ads](#twitter)
#
# ## Motivation <a name='motivation'></a>
#
# Proper audience targeting is a critical component of a successful advertising campaign. This study aims to identify customer demographics that may be particularly receptive to Game Revenant's (GR) advertising, specifically to optimize social media-based campaigns.
#
# Due to their large reach and popularity, Facebook, Instagram, and Twitter can be an effective means of reaching new audiences. Facebook (which owns Instagram) and Twitter both offer APIs that allow businesses to target their advertisements based on a number of demographic features, such as age, gender, language, location, and interests. This project aims to inform audience targeting based on interests.
#
# Analysis is performed on unstructured social media data, specifically from Twitter. Compared to other social media, Twitter's API allows greater access to user data, enabling more effective data mining. GR currently has too few followers on Twitter to allow for productive data mining. However, the Twitter accounts of rival companies can be analyzed as well. GR's game *Where Shadows Slumber* (WSS) is frequently compared to *Monument Valley*, a mobile puzzle game produced by USTWO Games, by game critics and customer reviewers. At the time of scraping, the USTWO Games Twitter account, @ustwogames, had over 126k followers.
#
# Customer interests were estimated by 1) examining the profile description of @ustogames followers, and 2) examining the most popular friends among @ustogames followers. Preprocessed descriptions were examined via two clustering approches, K-modes and
# DBSCAN. In Twitter's official terminology, a 'friend' is an account a user follows. The most popular friends were clustered via K-modes. The rationale behind the unorthodox application of K-modes will be explained later in the notebook.
#
#
# ## Clustering methods and results <a name='methodsresults'></a>
#
# ### Data exploration <a name='explore'></a>
#
# The Twitter profiles of @ustogames were mined via the python package Tweepy and written to a SQL database (refer to *pull_data_twitter.py* and *sqlite_fx.py* in my repository at https://github.com/vin-say/web-scraping/tree/master/twitter).

# %%
import pandas as pd
import sqlalchemy as sa
from pathlib import Path

# Move to main directory of the Customer-Segmentation project
# %cd ..

DB_NAME = 'customer-segmentation'
TAB_NAME = 'ustwo_followers'

# Pull data from SQLite DB
e = sa.create_engine('sqlite:///./data/interim/' + DB_NAME + '.sqlite')
query = 'SELECT * FROM ' + TAB_NAME
users = pd.read_sql_query(query, e)

users.head()
# Out:
# C:\Users\Vincent\Game-Revenant\Where-Shadows-Slumber\Customer-Segmentation
#                     id            id_string                name  \
# 0  1114109046792032256  1114109046792032256              Hiyoru
# 1  1120790192128954371  1120790192128954371  Tom Baines 🏳️‍🌈 🇪🇺
# 2            113652889            113652889     Marmalade Games
# 3            363116063            363116063            MIT SHAH
# 4            972169508            972169508        Kyrie E.H.C.
#
#       screen_name             location                      url  \
# 0         Hiyoru6                 None                     None
# 1     TomBaines16  North West, England                     None
# 2  MarmaladeGames           London, UK   http://t.co/sPUf5LShHE
# 3       mitshah97            Ahmedabad                     None
# 4        KyrieEHC          Madison, WI  https://t.co/ajE03P8x2g
#
#                                          description  protected  verified  \
# 0                          so para fotos de desenhos          0         0
# 1  Extreme sports calendar model. \nKeeping retro...          0         0
# 2                                               None          0         0
# 3                          #Unity3d #Game #Developer          0         0
# 4  Still believes in the warmth in interaction. S...          0         0
#
#    followers_count  friend_count  listed_count  favourites_count  \
# 0                1            21             0               139
# 1               29           169             0               961
# 2              506           262            13               304
# 3               39           279             1                22
# 4              333          1103            18              1118
#
#    statuses_count                      created_at  default_profile  \
# 0               5  Fri Apr 05 10:14:30 +0000 2019                1
# 1             456  Tue Apr 23 20:42:59 +0000 2019                0
# 2             471  Fri Feb 12 15:07:07 +0000 2010                0
# 3              13  Sat Aug 27 15:13:29 +0000 2011                1
# 4             734  Mon Nov 26 15:27:59 +0000 2012                0
#
#    default_profile_image
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0

# %%
print(str(len(users)) + ' @ustwogames follower profiles were mined')
# Out:
# 125925 @ustwogames follower profiles were mined

# %% [markdown]
# ### Text wrangling of profile descriptions <a name='wrangle'></a>
#
# Although a number of features were mined, only the profile description and identifying user ID are of interest in the proceeding analysis.
#
# Prior to analysis, unstructured text data must be preprocessed. Punctuation, emojis, and excess white space were removed. All words were converted to lowercase and tokenized. Stopwords were removed. The NLTK stopword list was extended by several words that were found to be common in profile descriptions, but did not add any useful information about user interests.

# %%
import nltk
import re
import numpy as np

def normalize_doc(doc, stop_words):
    ''' Basic text cleaning for English documents
    
    param doc (str): document to be cleaned
    param stop_words (str list): common words to be filtered out
    return clean_doc (str): cleaned document
    '''
    # remove special characters and white space. This filters out non-Latin languages!!
    doc = re.sub(r'[^a-zA-Z\s]', ' ', doc, re.IGNORECASE|re.ASCII)
    # remove single characters
    doc = re.sub(r'\b[a-zA-Z]\b', '', doc, re.IGNORECASE|re.ASCII)    
    # remove whitespace at beginning and end of string
    doc = doc.strip()
    # convert all characters to lowercase
    doc = doc.lower()
    # tokenize document
    tokens = nltk.word_tokenize(doc)
    # remove stop words
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # recreate doc from filtered tokens
    clean_doc = ' '.join(filtered_tokens)
    return clean_doc

stop_words = nltk.corpus.stopwords.words('english')
stop_words.extend(['co', 'https', 'http', 'gmail', 'com', 'like', 'love'])

users['clean_desc'] = users['description'].map(lambda doc: normalize_doc(doc, stop_words) 
                                                if doc is not None
                                                else np.nan)

users[['description','clean_desc']].head()
# Out:
#                                          description  \
# 0                          so para fotos de desenhos
# 1  Extreme sports calendar model. \nKeeping retro...
# 2                                               None
# 3                          #Unity3d #Game #Developer
# 4  Still believes in the warmth in interaction. S...
#
#                                           clean_desc
# 0                             para fotos de desenhos
# 1  extreme sports calendar model keeping retro al...
# 2                                                NaN
# 3                               unity game developer
# 4  still believes warmth interaction studied game...

# %% [markdown]
# The results after initial preprocessing are shown above. For now, only profile descriptions in English were analyzed. Language identification of short text is challenging, and the more common language identication libraries (e.g. langid) were inaccurately classifying certain profile descriptions. Facebook's FastText library offers an alternative that has shown relatively high accuracy with short text language classification (http://alexott.blogspot.com/2017/10/evaluating-fasttexts-models-for.html).
#
# English profiles were lemmatized using the NLP libary spaCy, completing the text preprocessing stage of the analysis pipeline. Lemmatization can take several minutes, so the updated DataFrame was saved to a csv file.

# %%
import os
import fasttext
import spacy

nlp = spacy.load('en') #download 'small' version of english model

def lemmatize_doc(doc):
    '''Apply spaCy lemmatization to a document (str)'''
    
    doc = nlp(doc)
    doc = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in doc])
    return doc

# import and apply FastText model for language identification
idlang_path = 'data/external/fasttext_training_data/lid.176.bin'
idlang_model = fasttext.FastText.load_model(idlang_path)

users['lang_id'] = users['clean_desc'].map(lambda doc: idlang_model.predict(doc) 
                                            if doc == doc 
                                            else np.nan)

# only English profiles are lemmatized; empty profiles are also ignored
users['clean_desc_en'] = users.apply(lambda row: lemmatize_doc(row['clean_desc']) 
                                        if  row['lang_id'] == row['lang_id']
                                        and row['lang_id'][0][0] == '__label__en'
                                        and row['clean_desc'] == row['clean_desc'] 
                                        else np.nan,
                                        axis=1)

# Push processed data into SQLite DB. Profiles with non-English or empty descriptions were dropped
e = sa.create_engine('sqlite:///./data/processed/' + DB_NAME + '-clean.sqlite')

cleaned_tab = TAB_NAME + '_clean'
users[['id', 'description', 'clean_desc_en']].to_sql(cleaned_tab, e, if_exists='replace')

users[['description','clean_desc','clean_desc_en']].head()
# Out:
#                                          description  \
# 0                          so para fotos de desenhos
# 1  Extreme sports calendar model. \nKeeping retro...
# 2                                               None
# 3                          #Unity3d #Game #Developer
# 4  Still believes in the warmth in interaction. S...
#
#                                           clean_desc  \
# 0                             para fotos de desenhos
# 1  extreme sports calendar model keeping retro al...
# 2                                                NaN
# 3                               unity game developer
# 4  still believes warmth interaction studied game...
#
#                                        clean_desc_en
# 0                                                NaN
# 1  extreme sport calendar model keep retro alive ...
# 2                                                NaN
# 3                               unity game developer
# 4  still believe warmth interaction study game cu...

# %% [markdown]
# ### Clustering users based on their profile descriptions <a name='clustering'></a>
#
# After preprocessing, the profile descriptions were clustered via two approaches, K-modes and DBSCAN.
#
# #### K-modes clustering <a name='kmodes'></a>
#
# Given the short length of a typical profile, a word will typically appear no more than once within a given profile description. *It would thus be more approriate to vectorize profile descriptions as binary categorical vectors, as opposed to numeric vectors.* Profile descriptions were count vectorized as binary categorical data, where a value of *1* would indicate that a given word was present in a given profile description.
#
#
# K-means is likely the most popular approach to clustering. However, its use is limited to numerical data. The K-modes algorithim was developed as an analog to K-means for categorical data (Huang 1997, 1998). Like K-means, the K-modes algorithim requires that the number of clusters be predetermined.
#
# The kmodes Python library was used to perform K-modes clustering. No optimal number of clusters was assumed a priori. Consequently, K-modes clustering for a a range of initial cluster numbers (2 through 20) was executed. Results were saved to a SQL database.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from kmodes.kmodes import KModes

DB_NAME = 'customer-segmentation-clean'
TAB_NAME = 'ustwo_followers_clean'
NUM_CLUSTERS_RNG = 16 #upper limit of cluster range to evaluate

# Pull processed data from SQLite DB
e = sa.create_engine('sqlite:///./data/processed/' + DB_NAME + '.sqlite')

#SQL query includes a WHERE statement that filters out NA values and empty strings
query = 'SELECT id, description, clean_desc_en FROM ' + TAB_NAME + ' WHERE clean_desc_en != \'\''
users = pd.read_sql_query(query, e)

cv = CountVectorizer(ngram_range=(1, 2), min_df=100, max_df=1.0,
                     stop_words=stop_words, binary=True)
cat_matrix = cv.fit_transform(users['clean_desc_en'])

# Connect to DB where cluster results are to be saved
DB_RESULTS_NAME = 'customer-segmentation-cluster'
e = sa.create_engine('sqlite:///./models/' + DB_RESULTS_NAME + '.sqlite')
TAB_RESULTS_PREFIX = 'ustwo_followers_k_'

for n_clusters in range(2, NUM_CLUSTERS_RNG):
    kmod = KModes(n_clusters=n_clusters, init='Huang', random_state=42, n_jobs=-1)
    y_pred = kmod.fit_predict(cat_matrix.toarray())
    users['cluster'] = kmod.labels_
    tab_name = TAB_RESULTS_PREFIX + str(n_clusters)
    users.to_sql(tab_name, e, if_exists='replace')
    print('k = ' + str(n_clusters) + ' clusters analyzed')
# Out:
# k = 2 clusters analyzed
# k = 3 clusters analyzed
# k = 4 clusters analyzed
# k = 5 clusters analyzed
# k = 6 clusters analyzed
# k = 7 clusters analyzed
# k = 8 clusters analyzed
# k = 9 clusters analyzed
# k = 10 clusters analyzed
# k = 11 clusters analyzed
# k = 12 clusters analyzed
# k = 13 clusters analyzed
# k = 14 clusters analyzed
# k = 15 clusters analyzed

# %% [markdown]
# The Kmodes algorithim will force the data to be organized into the predefined number of clusters. Clusters are not guaranteed to be generated in a meaningful way.
#
# In order to gauge the distinctiveness of the clusters, a vocabulary list of the most common unigrams, bigrams, and trigrams within the profile descriptions of a given cluster are generated (*gen_vocab_list*) and ordered by freqeuncy of occurance. The degree of similiarity in the top vocabulary between two clusters is a measure of the of the distance between those clusters.

# %%
from collections import Counter

def gen_vocab_list(corpus):
    ''' Generates a vocab list of unigrams, bigrams, and trigrams found in the corpus
    
    param corpus (str list): list containing documents from which vocab list will be derived
    return vocab (str list): list of vocab words found in the corpus
    '''
    unigrams = [words for doc in corpus for words in doc.split()]
    ngrams = [bigram for doc in corpus for bigram in nltk.ngrams(doc.split(), 2)]
    bigrams = [token[0] + ' ' + token[1] for token in ngrams]
    ngrams = [bigram for doc in corpus for bigram in nltk.ngrams(doc.split(), 3)]
    trigrams = [token[0] + ' ' + token[1] + ' ' + token[2] for token in ngrams]
    vocab = unigrams + bigrams + trigrams
    return vocab

def print_cluster_results(df, col_clust, col_list, clust_rng, n_keywords=10, n_desc=5):
    '''Evaluate clustering results by printing the most popular vocab words within a cluster corpus, and the prevalence of those words in the cluster corpus 
    
    param df (DataFrame): contains columns with profile features and cluster assignment
    param col_clust (str): name of column containing cluster assignment
    param col_list (str list): name of column containing corpus to be analyzed
    param clust_rng (tuple): bounds of the range of clusters to be printed. Assumes integer increments of 1. 
    param n_keywords (int): number of top vocab words to be analyzed for prevalence in the corpus
    param n_desc (int): number of randomly sampled twitter profiles whose features listed in col_list are to be printed
    '''
    n_total = len(df) 
    
    for cluster in range(clust_rng[0], clust_rng[1]):
        corpus = df.loc[df[col_clust] == cluster]
        n_corpus = len(corpus)
        per_label = round(n_corpus/n_total*100) # percentage of documents assigned to the cluster label 
        vocab = gen_vocab_list(corpus[col_list[0]])
        print('Cluster # ' + str(cluster))
        print(str(n_corpus) + ' (' + str(per_label) + '%) users with valid description in this cluster')
        print(Counter(vocab).most_common(n_keywords))
        if n_desc > 0:
            print(corpus[col_list].sample(n=n_desc))
        print('\n')

# %% [markdown]
# All the cluster results can then be analyzed, pulling the K-modes output from the database.

# %%
DB_NAME = 'customer-segmentation-cluster'
e = sa.create_engine('sqlite:///./models/' + DB_NAME + '.sqlite')

for n_clusters in range(2, NUM_CLUSTERS_RNG):

    TAB_NAME = 'ustwo_followers_k_' + str(n_clusters)
    query = 'SELECT id, clean_desc_en, cluster FROM ' + TAB_NAME + ' WHERE clean_desc_en != \'\''
    users = pd.read_sql_query(query, e)

    print('CLUSTER K = ' + str(n_clusters))
    print('\n')
    print_cluster_results(df=users, col_clust='cluster', col_list=['clean_desc_en'], clust_rng=(0,n_clusters))
# Out:
# CLUSTER K = 2
#
#
# Cluster # 0
# 47166 (98%) users with valid description in this cluster
# [('game', 10080), ('designer', 3933), ('make', 2676), ('developer', 2441), ('design', 2342), ('gamer', 2325), ('artist', 2257), ('video', 2101), ('play', 2036), ('follow', 1895)]
#                                            clean_desc_en
# 35439  quality engineer slackhq ex flickr photography...
# 13614                             mobile game io android
# 38072                        life short craft long learn
# 45946  writer student game player always order write ...
# 45428  interactioneer ceo vl ltb zvs make wuppet wupp...
#
#
# Cluster # 1
# 1058 (2%) users with valid description in this cluster
# [('creative', 1092), ('director', 335), ('creative director', 271), ('designer', 198), ('game', 189), ('design', 172), ('digital', 107), ('founder', 91), ('art', 90), ('studio', 76)]
#                                            clean_desc_en
# 6124   founder creative art director brokenrule game ...
# 16527  design creative speaking drum comedy refrigera...
# 11391  creative technology director leoburnettsyd ska...
# 6867        creative director design play runner cyclist
# 3370   ux designer product designer intralink inc lov...
#
#
# CLUSTER K = 3
#
#
# Cluster # 0
# 46024 (95%) users with valid description in this cluster
# [('game', 8348), ('designer', 3980), ('make', 2450), ('design', 2390), ('developer', 2373), ('gamer', 2275), ('artist', 2210), ('follow', 1809), ('work', 1753), ('art', 1725)]
#                                            clean_desc_en
# 37708  stream league legend live yyvuzadmrf watch hma...
# 18708                                         plz follow
# 27911  former public service officer lincoln police d...
# 45267   professional gamer prior military service member
# 30440  musician coffee addict independent game develo...
#
#
# Cluster # 1
# 773 (2%) users with valid description in this cluster
# [('stuff', 816), ('game', 216), ('make', 145), ('design', 77), ('designer', 71), ('thing', 63), ('art', 60), ('work', 54), ('artist', 49), ('tweet', 49)]
#                                            clean_desc_en
# 25016    father husband apple fan gamer tech lover stuff
# 44999  freelance ui artist cool project previously ui...
# 40390  man lifestyle site stuff guy sport humor mediu...
# 2354   word stuff really support artsy friend yell eu...
# 24505                           geek dad make game stuff
#
#
# Cluster # 2
# 1427 (3%) users with valid description in this cluster
# [('game', 1705), ('video', 1489), ('video game', 1341), ('play', 305), ('play video', 201), ('play video game', 197), ('make', 150), ('music', 116), ('youtube', 98), ('developer', 82)]
#                                            clean_desc_en
# 22698  multiball gaming go source thing game whether ...
# 30363  hello twitter double time game two youtube let...
# 34509  hey everyone currently work aerospace company ...
# 9996   illustrator writer whatever chronicle brave ea...
# 956    animator hallmark lab llc title card illustrat...
#
#
# CLUSTER K = 4
#
#
# Cluster # 0
# 37825 (78%) users with valid description in this cluster
# [('designer', 2801), ('design', 1833), ('gamer', 1826), ('make', 1616), ('follow', 1599), ('artist', 1525), ('youtube', 1369), ('life', 1286), ('gaming', 1234), ('developer', 1212)]
#                                            clean_desc_en
# 38070                          love callofduty minecraft
# 13822                                    designer london
# 28220  slacker build future interoperability email sl...
# 15376  ui designer ux design department renault gradu...
# 41419  ab fajr rynbhllrd editorial consultant sapelos...
#
#
# Cluster # 1
# 1106 (2%) users with valid description in this cluster
# [('lover', 1153), ('game', 299), ('designer', 173), ('music', 166), ('gamer', 138), ('artist', 105), ('thing', 97), ('developer', 90), ('music lover', 89), ('enthusiast', 82)]
#                                            clean_desc_en
# 27477  nature lover aspire vegan use dance instagram ...
# 5963   sassy smartass writer irreverent clever comeba...
# 45832  technology video game anime lover hobbyist pro...
# 25158  small business owner dog lover two luna mello ...
# 318    writer ope go midwestern narrative designer ge...
#
#
# Cluster # 2
# 8368 (17%) users with valid description in this cluster
# [('game', 9970), ('video', 1427), ('video game', 1282), ('developer', 1125), ('make', 1063), ('designer', 1039), ('play', 1037), ('game developer', 781), ('indie', 758), ('artist', 648)]
#                                            clean_desc_en
# 26316           developer focus game ai art intersection
# 8695   illustrator designer base seattle make cutie p...
# 3051   official account byrtnsw jy niche video game w...
# 1029   storyteller writer broadcaster bafta judge voi...
# 4197   game developer work super secret stuff ask buy...
#
#
# Cluster # 3
# 925 (2%) users with valid description in this cluster
# [('founder', 968), ('designer', 118), ('director', 111), ('ceo', 89), ('design', 89), ('creative', 71), ('developer', 69), ('digital', 54), ('product', 52), ('founder ceo', 51)]
#                                            clean_desc_en
# 11730  founder coo falldamage previously development ...
# 47951  founder president younghorse creator octodadga...
# 291    founder theantigallery freelance curator creat...
# 29048      founder chief innovation officer strategy lab
# 28518  artist writer creator puk comic_strip founder ...
#
#
# CLUSTER K = 5
#
#
# Cluster # 0
# 3365 (7%) users with valid description in this cluster
# [('designer', 3469), ('graphic', 556), ('game', 489), ('graphic designer', 470), ('ux', 464), ('design', 356), ('product', 336), ('illustrator', 333), ('artist', 301), ('ui', 278)]
#                                            clean_desc_en
# 7426                                   dead end designer
# 4501   freelance ux designer founder comboldn part us...
# 38540                    designer illustrator teambition
# 39660  comicker illustrator animator designer phoenix...
# 12408                                   graphic designer
#
#
# Cluster # 1
# 740 (2%) users with valid description in this cluster
# [('stuff', 782), ('game', 225), ('make', 131), ('design', 70), ('art', 58), ('thing', 56), ('video', 55), ('tweet', 45), ('music', 44), ('work', 41)]
#                                            clean_desc_en
# 488                                  lol stuff one place
# 27587  run cycling geek stuff currently chair bellaro...
# 13892  game game game oh yeah movie course sciency st...
# 30322  design stuff fdk studio music lover gamer trav...
# 3022   cynical view world stuff since front end devel...
#
#
# Cluster # 2
# 42667 (88%) users with valid description in this cluster
# [('game', 8452), ('make', 2319), ('gamer', 2121), ('developer', 2086), ('design', 2005), ('video', 1893), ('play', 1837), ('artist', 1833), ('follow', 1787), ('youtube', 1553)]
#                                            clean_desc_en
# 24067     official uk twitt feed amazon appstore android
# 17771                                streamer abyss clan
# 6211   mind man capable anything everything past well...
# 11452                  design lead us gamer wine drinker
# 9211                                      student buddha
#
#
# Cluster # 3
# 836 (2%) users with valid description in this cluster
# [('also', 856), ('game', 278), ('play', 126), ('make', 103), ('video', 87), ('youtube', 81), ('follow', 76), ('video game', 65), ('gamer', 63), ('thing', 61)]
#                                            clean_desc_en
# 42780  product redbubble mixed medium artist food hea...
# 45856  lettercraftapp new innovative word game io ava...
# 38630  name denuel john bueno twitter account barely ...
# 36588  guy cook thing also thing either gaming alter ...
# 6195   thing michigan graphic design photography gami...
#
#
# Cluster # 4
# 616 (1%) users with valid description in this cluster
# [('game', 825), ('designer', 662), ('game designer', 624), ('artist', 90), ('work', 65), ('developer', 60), ('make', 55), ('founder', 43), ('writer', 42), ('programmer', 41)]
#                                            clean_desc_en
# 4905   technical game designer lot thing almost ok cu...
# 10872  father game designer teacher pedagogical direc...
# 4453   game designer narrative system culture game ga...
# 32641         animator day code night game designer time
# 10124  game designer focus narrative ai garbage anime...
#
#
# CLUSTER K = 6
#
#
# Cluster # 0
# 43812 (91%) users with valid description in this cluster
# [('game', 9153), ('designer', 3500), ('make', 2472), ('developer', 2313), ('gamer', 2217), ('artist', 2088), ('video', 1961), ('play', 1937), ('work', 1666), ('follow', 1644)]
#                                            clean_desc_en
# 26631                                        turn nation
# 15353            unity developer focus mobile game vr ar
# 10535              story inspiration behind maker admire
# 35142  political science santannapisa intern antitrus...
# 1184   super intuitive retro revival mobile game whol...
#
#
# Cluster # 1
# 1095 (2%) users with valid description in this cluster
# [('director', 1137), ('creative', 328), ('art', 288), ('creative director', 269), ('game', 241), ('art director', 237), ('designer', 200), ('design', 173), ('founder', 139), ('digital', 86)]
#                                            clean_desc_en
# 35649                              creative director ink
# 44721               art director designer sr ad fivedone
# 819    make eraseallkitten online adventure game insp...
# 45657  director alumnus relation newark academy dad m...
# 26718             indie game developer creative director
#
#
# Cluster # 2
# 2118 (4%) users with valid description in this cluster
# [('design', 2330), ('game', 639), ('designer', 338), ('art', 284), ('game design', 266), ('graphic', 229), ('ux', 221), ('product', 199), ('digital', 153), ('graphic design', 145)]
#                                            clean_desc_en
# 2709   final year game design rmit witch founder blue...
# 23363  data scientist vedraio interested science tech...
# 39496  ifbqrg print design policy brand management gr...
# 10618  father ux consultant ux product designer passi...
# 10706  game designer sae graduate developer lightweav...
#
#
# Cluster # 3
# 163 (0%) users with valid description in this cluster
# [('day', 170), ('night', 163), ('game', 61), ('designer', 34), ('developer', 32), ('designer day', 19), ('work', 18), ('indie', 17), ('artist', 16), ('dev', 16)]
#                                            clean_desc_en
# 19789  swizzle bit manticore game day roundguardgame ...
# 1681   game design development day medium art music n...
# 30754       designer day night game immersive experience
# 22898                 procrastinator day developer night
# 2713   make cool app stuff frontend designer day back...
#
#
# Cluster # 4
# 485 (1%) users with valid description in this cluster
# [('hi', 487), ('game', 111), ('name', 84), ('follow', 67), ('hi name', 63), ('play', 56), ('youtube', 55), ('video', 51), ('make', 45), ('i', 43)]
#                                            clean_desc_en
# 24323  hi pc minecraft name peaceonminecraft official...
# 38594                         hi year old suck life bios
# 18666                           hi youtuber gaming stuff
# 17860                                      hi video game
# 28516                                   hi follow follow
#
#
# Cluster # 5
# 551 (1%) users with valid description in this cluster
# [('instagram', 554), ('follow', 175), ('follow instagram', 86), ('youtube', 79), ('game', 64), ('snapchat', 61), ('facebook', 41), ('artist', 40), ('designer', 36), ('gamer', 32)]
#                                            clean_desc_en
# 18228  hey guy classicpsycho game channel youtube any...
# 19057  follow instagram baby lightskin follow snap de...
# 11540                                instagram heymandym
# 8330   eg ti dz writer content creator longing life g...
# 34947  i be damn awesome yrs old hempenthusiast baby ...
#
#
# CLUSTER K = 7
#
#
# Cluster # 0
# 45812 (95%) users with valid description in this cluster
# [('game', 8663), ('designer', 3879), ('make', 2539), ('developer', 2378), ('gamer', 2251), ('artist', 2048), ('play', 1907), ('video', 1907), ('follow', 1778), ('design', 1736)]
#                                            clean_desc_en
# 22841   play game make youtube video go check hetkqearui
# 12882  cut rope catsthegame kingthieve creator get ga...
# 34509  hey everyone currently work aerospace company ...
# 22234                                         video game
# 479    artist astrophotographer lje gar ey elitedange...
#
#
# Cluster # 1
# 33 (0%) users with valid description in this cluster
# [('product', 35), ('head', 34), ('head product', 18), ('design', 8), ('ux', 7), ('father', 4), ('founder', 4), ('product design', 4), ('geek', 3), ('tweet', 3)]
#                                            clean_desc_en
# 32378  head product bossa studio game evangelist roun...
# 45074  head product back market bass player geek mobi...
# 31992  francesco belli head global product buongiorno...
# 44226  head ux software product designer aandrewallia...
# 20468  product convo health twitter head music booker...
#
#
# Cluster # 2
# 222 (0%) users with valid description in this cluster
# [('game', 262), ('gaming', 245), ('video', 49), ('play', 49), ('youtube', 30), ('video game', 28), ('news', 27), ('channel', 26), ('follow', 25), ('gamer', 22)]
#                                            clean_desc_en
# 40114  official twitter get next gaming youtube chann...
# 31480  fun love group casual player look create enjoy...
# 18944   graphic programmer maker game stuff gaming stuff
# 31859  passionate agile software development people r...
# 15272  developer gaming entertainment online medium s...
#
#
# Cluster # 3
# 1088 (2%) users with valid description in this cluster
# [('game', 1141), ('art', 746), ('design', 736), ('game design', 270), ('designer', 174), ('artist', 128), ('make', 127), ('game art', 127), ('video', 114), ('student', 102)]
#                                            clean_desc_en
# 30647       game design lecturer essentially child beard
# 37812  founder environment artist infuse studio neq a...
# 10412  art admirer video tabletop game enthusiast pla...
# 6386   game art student study warwickshire college ar...
# 6659   digitalhealth enthusiast mission fight stress ...
#
#
# Cluster # 4
# 42 (0%) users with valid description in this cluster
# [('follow', 46), ('good', 45), ('game', 15), ('us', 8), ('one', 6), ('twitch', 6), ('follow good', 6), ('news', 5), ('follow us', 5), ('online', 4)]
#                                            clean_desc_en
# 28609  follow us find good game play iphone android s...
# 27342  hey good old friend reuse shoutout follow yyou...
# 6574   hi osmonaut game follow game industry passiona...
# 31557  yo yo yo mah good look people mason lugg new f...
# 17589  wan na super male model huge huge fan taylor s...
#
#
# Cluster # 5
# 918 (2%) users with valid description in this cluster
# [('live', 954), ('life', 187), ('game', 160), ('live life', 95), ('stream', 74), ('work', 67), ('play', 64), ('live stream', 58), ('make', 57), ('video', 57)]
#                                            clean_desc_en
# 47059  provide happiness family member inspire people...
# 36332                                   write email live
# 25975                         graphic designer live oslo
# 46277  graphic designer illustrator north live work w...
# 14452  project developer vrtual deputy ceo nextrealit...
#
#
# Cluster # 6
# 109 (0%) users with valid description in this cluster
# [('artist', 112), ('writer', 111), ('artist writer', 39), ('game', 26), ('writer artist', 20), ('designer', 17), ('gamer', 16), ('lover', 11), ('musician', 9), ('make', 8)]
#                                            clean_desc_en
# 4589   draw write read video game anime culture aspir...
# 34701  desktop publish doc image edit artist virtual ...
# 41666  draw chew image comic_strip writer artist farm...
# 1149   evie calvin leveille fake gamer girl tis lvl g...
# 47962  gamedev comic writer artist work many game wri...
#
#
# CLUSTER K = 8
#
#
# Cluster # 0
# 1428 (3%) users with valid description in this cluster
# [('game', 1706), ('video', 1490), ('video game', 1341), ('play', 305), ('play video', 201), ('play video game', 197), ('make', 150), ('music', 116), ('youtube', 98), ('developer', 82)]
#                                            clean_desc_en
# 8156   enjoy walk talk eat video game movie mythology...
# 20199  jesse pvp good prankster ever qrygonlvbc subie...
# 27387  baltimore raven play video game also red vs bl...
# 32615                                    play video game
# 37826  mazlynify gaming channel youtube enjoy play vi...
#
#
# Cluster # 1
# 7183 (15%) users with valid description in this cluster
# [('game', 8563), ('developer', 1081), ('designer', 1006), ('make', 925), ('game developer', 760), ('play', 748), ('indie', 736), ('artist', 622), ('game designer', 605), ('work', 590)]
#                                            clean_desc_en
# 3320   indie game dev make golf fun join party lif bd...
# 18284                                       game awesome
# 17227  professional gamer game developer wait mention...
# 26565  brand new youtube channel everything cod gbs p...
# 45692  independent solo game dev contact need music a...
#
#
# Cluster # 2
# 1297 (3%) users with valid description in this cluster
# [('developer', 1333), ('web', 220), ('software', 190), ('designer', 183), ('io', 157), ('web developer', 145), ('software developer', 144), ('io developer', 98), ('end', 90), ('app', 89)]
#                                            clean_desc_en
# 46221                        frontend developer designer
# 7091   developer consultant podcaster localhostfm lev...
# 45379          application developer stereo photographer
# 4122   developer pikbomb studio follow us onetmxoy ky...
# 43379  people picture word bit work ydmfdjbg support ...
#
#
# Cluster # 3
# 1305 (3%) users with valid description in this cluster
# [('youtube', 1375), ('channel', 516), ('youtube channel', 426), ('check', 260), ('subscribe', 259), ('gaming', 215), ('video', 188), ('gamer', 174), ('follow', 157), ('check youtube', 145)]
#                                            clean_desc_en
# 19379                        youtube fun gaming wzivnmyd
# 18987                    subscribe savage gaming youtube
# 22536  hey name justin beginning youtuber youtube nam...
# 17807                       yo wayzzz youtube xtzg mhijn
# 22586  gt wow frogman xbox one gaming destiny deadly ...
#
#
# Cluster # 4
# 36227 (75%) users with valid description in this cluster
# [('designer', 2796), ('design', 1892), ('gamer', 1665), ('artist', 1521), ('make', 1434), ('follow', 1403), ('life', 1262), ('art', 1239), ('thing', 1128), ('work', 1093)]
#                                            clean_desc_en
# 46734                          creative director tellart
# 34905  simple download single alzybtaluk help charity...
# 11553                        work target alley xa nlzdsn
# 7634                                ugfjhavrqb unfo nsfw
# 38774  optical clan black op message skatemanh xbox j...
#
#
# Cluster # 5
# 242 (1%) users with valid description in this cluster
# [('musician', 243), ('artist', 44), ('designer', 36), ('gamer', 30), ('writer', 23), ('composer', 18), ('director', 16), ('designer musician', 16), ('creative', 15), ('music', 15)]
#                                            clean_desc_en
# 20676                       arie musician taruna andigha
# 7465    musician sound eece major gryffindor house stark
# 25535  worship pastor localchurchgr grandrapid mi hus...
# 41211  digital junkie cat person part time musician g...
# 25037  web dev ux engineer occasional musician study ...
#
#
# Cluster # 6
# 292 (1%) users with valid description in this cluster
# [('see', 305), ('thing', 23), ('follow', 22), ('world', 21), ('get', 19), ('guy', 18), ('come', 17), ('make', 17), ('one', 17), ('life', 17)]
#                                            clean_desc_en
# 28029  teen step life style loop get see age kik neon...
# 5035   friend star moon art check medium see drawing ...
# 34158  see get lot bit get able bit way new york year...
# 27953        test see affect social medium today society
# 14281  sniping trickshotte team lead lopeyffa want jo...
#
#
# Cluster # 7
# 250 (1%) users with valid description in this cluster
# [('movie', 254), ('music', 65), ('lover', 32), ('fan', 25), ('gamer', 25), ('tv', 25), ('book', 25), ('enthusiast', 23), ('art', 20), ('tech', 20)]
#                                            clean_desc_en
# 27103  plutotv free online television service broadca...
# 32828  lover wife french wine formula dad rock fancy ...
# 14648             movie fat thing line sticker ewhwi lsl
# 32071       make movie kim jong un north korean dictator
# 11130  huge nerd movie music aficionado stan life hal...
#
#
# CLUSTER K = 9
#
#
# Cluster # 0
# 35017 (73%) users with valid description in this cluster
# [('gamer', 1811), ('design', 1597), ('follow', 1501), ('artist', 1360), ('youtube', 1226), ('life', 1221), ('gaming', 1185), ('developer', 1108), ('art', 1070), ('music', 1058)]
#                                            clean_desc_en
# 42661  head technical solution thenbs optimist write ...
# 32339  io android ds vita window phone news feature r...
# 898                                   independent studio
# 9029                                                  nd
# 28724                                dreamer never learn
#
#
# Cluster # 1
# 196 (0%) users with valid description in this cluster
# [('game', 239), ('programmer', 201), ('designer', 62), ('game programmer', 50), ('developer', 48), ('game designer', 39), ('game developer', 38), ('work', 30), ('artist', 27), ('make', 26)]
#                                            clean_desc_en
# 10755  cricketer inventor android app game programmer...
# 29363  one man game develop studio designer programme...
# 39182  engineer computer science waveengine team memb...
# 36663  game programmer designer founder guard crush l...
# 1831   cgt student abertayuni stem vga ambassador pro...
#
#
# Cluster # 2
# 2442 (5%) users with valid description in this cluster
# [('make', 2584), ('game', 1141), ('make game', 348), ('thing', 257), ('video', 182), ('designer', 180), ('youtube', 167), ('work', 154), ('stuff', 148), ('play', 144)]
#                                            clean_desc_en
# 4376                            ryan make art xgjhtockgc
# 36406  happily make game filthy casual trailer park b...
# 24405  lover great stuff come norfolk book thing spar...
# 34146  feel growl new competitive team try make big l...
# 21669                   make custom zombie map call duty
#
#
# Cluster # 3
# 1399 (3%) users with valid description in this cluster
# [('game', 1672), ('video', 1458), ('video game', 1341), ('play', 296), ('play video', 201), ('play video game', 197), ('music', 115), ('make', 114), ('youtube', 86), ('developer', 81)]
#                                            clean_desc_en
# 33207  terence tolman lil brother matt play video gam...
# 27961                  video game dankest meme cat video
# 30239                video game xbox live xsightaimkillx
# 25946  really enjoy meet new people listen music watc...
# 16267  editor phma xhc magazine fabulate world virtua...
#
#
# Cluster # 4
# 49 (0%) users with valid description in this cluster
# [('go', 57), ('get', 53), ('follow', 14), ('go get', 12), ('back', 8), ('make', 7), ('game', 7), ('life', 6), ('try', 6), ('know', 5)]
#                                            clean_desc_en
# 20347       ncr life hqoomle yy get shoot prank go wrong
# 14986  software guy pixel lover game maker space love...
# 25773  student illustration work towards game buildin...
# 34868  gamer year still go maybe bad other get mad fr...
# 40378  be not get snapback go back home page marjijua...
#
#
# Cluster # 5
# 120 (0%) users with valid description in this cluster
# [('hate', 125), ('love', 12), ('people', 10), ('know', 7), ('lover', 7), ('game', 7), ('thing', 7), ('stuff', 7), ('school', 6), ('friend', 6)]
#                                            clean_desc_en
# 25280                  hate us cuz be not us arian proud
# 20164                           brittanyventi hate troll
# 22395                                      hate attitude
# 19969  hi play game hate stop play usually stream nic...
# 4182   write code nobody ask since demi dms open gith...
#
#
# Cluster # 6
# 3649 (8%) users with valid description in this cluster
# [('designer', 3788), ('game', 980), ('graphic', 521), ('game designer', 506), ('ux', 452), ('graphic designer', 437), ('design', 374), ('artist', 337), ('product', 325), ('illustrator', 322)]
#                                            clean_desc_en
# 43001                 product designer tweeting ptbr eng
# 42720    lead game designer founder bedtime digital game
# 27489                              designer destn design
# 6980   ux designer blizzard ent esport web dog overwa...
# 2587   freelance designer writer mixtape guru master ...
#
#
# Cluster # 7
# 156 (0%) users with valid description in this cluster
# [('game', 187), ('player', 161), ('game player', 26), ('developer', 24), ('play', 23), ('player game', 19), ('designer', 17), ('game developer', 16), ('make', 14), ('mobile', 12)]
#                                            clean_desc_en
# 27902               game hate player hate game soldy non
# 20043  illustrator game player friendly guy general c...
# 37173  founder ceo wizit game studio horrible bass gu...
# 45560  game player ex maker swimrunner sneakerwearer ...
# 46022                  game player game scholar lecturer
#
#
# Cluster # 8
# 5196 (11%) users with valid description in this cluster
# [('game', 6036), ('developer', 819), ('play', 611), ('game developer', 608), ('indie', 573), ('indie game', 443), ('artist', 417), ('dev', 386), ('work', 382), ('studio', 369)]
#                                            clean_desc_en
# 42015  husband father author principal thebiggerdesig...
# 14146  biz info mgmt dataviz consultant gwi aus brisb...
# 43779  tech store full tech peep fun keep people game...
# 6856   lead artist game konsuifighter freelance anima...
# 33348  gamer life youtuber wannabe kind game console ...
#
#
# CLUSTER K = 10
#
#
# Cluster # 0
# 2377 (5%) users with valid description in this cluster
# [('developer', 2465), ('game', 1374), ('game developer', 790), ('designer', 290), ('indie', 289), ('web', 276), ('software', 252), ('io', 217), ('work', 205), ('indie game', 203)]
#                                            clean_desc_en
# 3055   founder developer lyrelarkgame artist twocakesdev
# 16640             game developer artist environmentalist
# 5276   game developer pubg corp work map content ex a...
# 9242     musician mobile developer sporadic pixel artist
# 8920                  full stack developer picture horse
#
#
# Cluster # 1
# 32476 (67%) users with valid description in this cluster
# [('designer', 1972), ('design', 1642), ('follow', 1388), ('make', 1377), ('youtube', 1152), ('life', 1105), ('gaming', 1094), ('art', 986), ('music', 980), ('thing', 978)]
#                                            clean_desc_en
# 23078  clan call duty xbox hope guy clan note guy cla...
# 44772  small independent publisher specialize interac...
# 42868  ikerbasque research fellow neuroscientist brai...
# 29756            hey check twitch account brandon harris
# 28036                                               year
#
#
# Cluster # 2
# 7344 (15%) users with valid description in this cluster
# [('game', 8687), ('video', 1360), ('video game', 1225), ('play', 1006), ('make', 965), ('designer', 893), ('artist', 559), ('game designer', 558), ('work', 533), ('indie', 520)]
#                                            clean_desc_en
# 46070  tokyo base game lover gatherer founder egm nom...
# 20344  gaming xbox one decent size variety game look ...
# 38439       fail make game fail fail better wait gamedev
# 13465  welcome chilli aspire game dev smash nintendo ...
# 946    unassuming product designer great critic bad game
#
#
# Cluster # 3
# 1084 (2%) users with valid description in this cluster
# [('work', 1112), ('designer', 123), ('currently', 102), ('artist', 100), ('currently work', 83), ('design', 82), ('art', 65), ('thing', 64), ('make', 61), ('hard', 59)]
#                                            clean_desc_en
# 8418   work family school library integrate community...
# 21855  dad mac lover business focus technical guy ele...
# 44457  twenty something live liverpool manchester wor...
# 25489           make music video work thought would part
# 29632  ba art interactive medium work information tec...
#
#
# Cluster # 4
# 1787 (4%) users with valid description in this cluster
# [('gamer', 1847), ('youtube', 174), ('xbox', 150), ('play', 122), ('lover', 117), ('gaming', 102), ('youtuber', 97), ('follow', 95), ('ps', 92), ('artist', 90)]
#                                            clean_desc_en
# 16520                      photographer gamer programmer
# 37700                       gamer musician food consumer
# 16365  veteran gamer steamer newbie ow tk mhw sekiro ...
# 17835  guess milk follow follow back bias dragon jiyo...
# 39075                 play fortnite worldoftank pc gamer
#
#
# Cluster # 5
# 695 (1%) users with valid description in this cluster
# [('time', 761), ('full', 91), ('full time', 88), ('one', 73), ('part', 73), ('part time', 70), ('make', 52), ('good', 46), ('life', 40), ('day', 32)]
#                                            clean_desc_en
# 25561  paranormal investigator part time prep cook po...
# 38474  year old gay salamence furry dragon ad roar ra...
# 4086   run time hold close run time man yeah lost mom...
# 44240  ticklish laugh loudly dreamer snore loudly lea...
# 12186  digital engineering test centre joint industry...
#
#
# Cluster # 6
# 529 (1%) users with valid description in this cluster
# [('designer', 570), ('graphic', 544), ('graphic designer', 476), ('illustrator', 98), ('game', 63), ('design', 63), ('artist', 61), ('designer illustrator', 50), ('graphic designer illustrator', 47), ('motion', 44)]
#                                            clean_desc_en
# 5365   virat kohli cricket technology entertainment a...
# 36096  full time graphic designer part time crazy cat...
# 14205  graphic designer bangkok university instagram ...
# 11606  nerd good find christ graphic designer love cr...
# 45912  graphic designer illustrator constantly work e...
#
#
# Cluster # 7
# 114 (0%) users with valid description in this cluster
# [('game', 145), ('review', 123), ('game review', 41), ('video', 35), ('news', 34), ('video game', 25), ('play', 16), ('us', 14), ('late', 14), ('app', 14)]
#                                            clean_desc_en
# 12882  cut rope catsthegame kingthieve creator get ga...
# 7412   dog guy manager author game throne former seni...
# 2958   come pizza stay indie game review bwpb bcg fol...
# 16216  everyone critic check review movie game comic_...
# 13735  six month later game review analyse game six m...
#
#
# Cluster # 8
# 570 (1%) users with valid description in this cluster
# [('tweet', 587), ('design', 63), ('follow', 46), ('tech', 40), ('product', 40), ('thing', 39), ('digital', 36), ('opinion', 34), ('stuff', 34), ('designer', 32)]
#                                            clean_desc_en
# 2885   software engineer proud owner commodore twitte...
# 4188                              tweet less often would
# 34324  tweet opinion care tech liberalism refugee pri...
# 8629   use tweet violin book yarn cook timeline invad...
# 40251  use tweet sport bxscience cmu viz number mostl...
#
#
# Cluster # 9
# 1248 (3%) users with valid description in this cluster
# [('artist', 1300), ('designer', 152), ('illustrator', 133), ('art', 123), ('concept', 80), ('concept artist', 74), ('animator', 73), ('writer', 65), ('freelance', 63), ('artist illustrator', 62)]
#                                            clean_desc_en
# 1901           streamer speedrunn editor artist vyjpsxcn
# 39232  artist writer create nickelodeon short shelf r...
# 43178  art director ui artist corsegame videogame pas...
# 33111                                       kinda artist
# 45494                                       comic artist
#
#
# CLUSTER K = 11
#
#
# Cluster # 0
# 41754 (87%) users with valid description in this cluster
# [('game', 8430), ('designer', 3601), ('developer', 2250), ('make', 2228), ('gamer', 2070), ('design', 1949), ('artist', 1920), ('video', 1783), ('play', 1696), ('follow', 1565)]
#                                            clean_desc_en
# 33339                      soul music lover dj collector
# 37733  current twitt refuge joe fielder underworld as...
# 30524  currently engage amazing woman brittanygmez ma...
# 5786                              industrial ux designer
# 26097  plasterer thing plaster related mission delive...
#
#
# Cluster # 1
# 609 (1%) users with valid description in this cluster
# [('create', 620), ('game', 303), ('design', 69), ('experience', 66), ('studio', 62), ('designer', 60), ('art', 52), ('world', 45), ('make', 45), ('indie', 44)]
#                                            clean_desc_en
# 42114  tale stuff brand new web cartoon series create...
# 4388                                     business create
# 28784  passionate internet marketing ux digital marke...
# 12838  guy make game gentlymadgame love create graphi...
# 2871   frontend wingify typescript fan indie game dev...
#
#
# Cluster # 2
# 371 (1%) users with valid description in this cluster
# [('see', 386), ('game', 74), ('make', 31), ('follow', 28), ('video', 28), ('guy', 28), ('thing', 27), ('new', 27), ('world', 25), ('life', 23)]
#                                            clean_desc_en
# 19419  guy laptrap make youtube video make gaming vol...
# 44347  one direction life happen see wish would messa...
# 46799  contributor fakeapstylebook kevin church profe...
# 26864  choose unseen know people want see sometimes h...
# 28029  teen step life style loop get see age kik neon...
#
#
# Cluster # 3
# 1687 (3%) users with valid description in this cluster
# [('art', 1790), ('game', 593), ('design', 307), ('director', 283), ('artist', 236), ('designer', 236), ('art director', 236), ('music', 153), ('make', 134), ('game art', 122)]
#                                            clean_desc_en
# 45505                       strategy design art bike dad
# 44926  illustrator art director creative producer google
# 33692  creative developer work unity art director mar...
# 36482  trickster art gamedev studio monolisk hacker w...
# 36310  typical explorer total gamer problem solver de...
#
#
# Cluster # 4
# 470 (1%) users with valid description in this cluster
# [('manager', 484), ('product', 103), ('game', 85), ('product manager', 83), ('project', 50), ('project manager', 46), ('community', 44), ('designer', 42), ('digital', 40), ('design', 39)]
#                                            clean_desc_en
# 25379                                      manager agent
# 14538  senior project manager pmp certify engineer un...
# 33376                                    bballhd manager
# 39333               product development manager svttu pj
# 29581                                    product manager
#
#
# Cluster # 5
# 223 (0%) users with valid description in this cluster
# [('visual', 224), ('designer', 95), ('visual designer', 53), ('artist', 47), ('design', 44), ('game', 34), ('visual artist', 24), ('illustrator', 20), ('work', 18), ('creative', 15)]
#                                            clean_desc_en
# 13626  visual artist draw paint often think book fash...
# 5232   sound designer specialise interactive audio ga...
# 1466          second year visual design student fond yam
# 42037  fan archetype myth secret storytelle symbol rp...
# 11896  visual designer easy distract animal look new ...
#
#
# Cluster # 6
# 496 (1%) users with valid description in this cluster
# [('fun', 513), ('game', 220), ('make', 105), ('play', 64), ('video', 45), ('gamer', 39), ('gaming', 36), ('new', 33), ('follow', 32), ('youtube', 30)]
#                                            clean_desc_en
# 28769  theme song hgzftxkid full lyric qedobhias pick...
# 47066                                         fun gineer
# 37364  new account fun play cod rust lol gta minecraf...
# 24320                                           game fun
# 36087                 make world fun place one game time
#
#
# Cluster # 7
# 749 (2%) users with valid description in this cluster
# [('team', 812), ('game', 170), ('competitive', 79), ('look', 73), ('player', 66), ('gaming', 60), ('new', 55), ('call', 55), ('make', 52), ('us', 52)]
#                                            clean_desc_en
# 31653  team motivation recruiting player represent mo...
# 12841  small uk indiedev team work bring unique new g...
# 19709  sniping trickshoting team would join add us in...
# 42461  i be aspire pro dota player do not team yet th...
# 21247  official fantomsnake gaming twitter page new n...
#
#
# Cluster # 8
# 874 (2%) users with valid description in this cluster
# [('go', 923), ('youtube', 139), ('game', 137), ('follow', 121), ('channel', 105), ('check', 86), ('play', 78), ('subscribe', 73), ('go check', 72), ('video', 69)]
#                                            clean_desc_en
# 2959   gamer year old also musician side welcome page...
# 7360   favorite quote piemation fuck i be suction cup...
# 16078                             goal accomplish one go
# 42597  go live life fullest take one day time along w...
# 18754  hai i be fambae would guy follow go sub channe...
#
#
# Cluster # 9
# 508 (1%) users with valid description in this cluster
# [('come', 523), ('game', 143), ('soon', 112), ('come soon', 98), ('play', 60), ('new', 51), ('follow', 49), ('youtube', 48), ('channel', 46), ('check', 41)]
#                                            clean_desc_en
# 28378  hype back make vid stream twitch lot cool thin...
# 30979  gamer upcoming streamer work hard make dream c...
# 179    come exhibition year work ncad degree end year...
# 12828                    color morph come end thank play
# 37555  guy come random tiny island call malta fronten...
#
#
# Cluster # 10
# 483 (1%) users with valid description in this cluster
# [('know', 513), ('game', 80), ('guy', 41), ('want', 38), ('get', 36), ('also', 33), ('make', 32), ('play', 31), ('thing', 30), ('follow', 30)]
#                                            clean_desc_en
# 5692   youtuber well know enjoy make let play video h...
# 45440  animator illustrator game maker animal pal lor...
# 47966  pinapp award win mobile app discovery service ...
# 28972  lover game music movie stay thoughtful among c...
# 8188                    know game money follow free yeah
#
#
# CLUSTER K = 12
#
#
# Cluster # 0
# 437 (1%) users with valid description in this cluster
# [('official', 443), ('twitt', 139), ('official twitt', 129), ('twitter', 125), ('account', 123), ('game', 94), ('official twitter', 86), ('page', 74), ('youtube', 51), ('twitter account', 48)]
#                                            clean_desc_en
# 42595  dqwkyan source xbox one news entertainment off...
# 27414  official twitter esport documentary allworkall...
# 31189  hey guy tis official twitter account psn guy o...
# 33726  official uspcgame account follow us break news...
# 36956  official twitter account savethecitygame curre...
#
#
# Cluster # 1
# 278 (1%) users with valid description in this cluster
# [('talk', 286), ('game', 121), ('video', 43), ('video game', 38), ('make', 27), ('talk game', 24), ('design', 21), ('want', 20), ('thing', 20), ('music', 19)]
#                                            clean_desc_en
# 9425   laude strategy design full stack development l...
# 42228  lecturer psychology phd researcher non binary ...
# 8156   enjoy walk talk eat video game movie mythology...
# 15985  gamer podcaster writing problem also talk spor...
# 36041  wannabe dota player hope get small community t...
#
#
# Cluster # 2
# 32898 (68%) users with valid description in this cluster
# [('designer', 2463), ('gamer', 1586), ('design', 1569), ('artist', 1314), ('follow', 1247), ('make', 1208), ('developer', 1116), ('life', 1100), ('music', 1042), ('art', 1017)]
#                                            clean_desc_en
# 33050        motion graphic designer life without motion
# 25780  copywriter literary persuader pr epson europe ...
# 31498  narrative designer producer play endless forme...
# 39583                                  write eat cooking
# 2292   finally come term bad driver world twitter goa...
#
#
# Cluster # 3
# 1132 (2%) users with valid description in this cluster
# [('good', 1196), ('game', 269), ('make', 105), ('friend', 87), ('play', 80), ('time', 69), ('life', 66), ('designer', 65), ('design', 60), ('video', 58)]
#                                            clean_desc_en
# 38784                    chaotic good follow verify user
# 32447  one leader sir look good call duty player pref...
# 17976  rich need couple thing compassion friend enemy...
# 28220  slacker build future interoperability email sl...
# 40504  big nintendo fan also enjoy sony drink much co...
#
#
# Cluster # 4
# 906 (2%) users with valid description in this cluster
# [('student', 910), ('game', 280), ('design', 130), ('art', 99), ('artist', 65), ('science', 65), ('university', 62), ('developer', 61), ('design student', 60), ('game design', 54)]
#                                            clean_desc_en
# 41260                                current student wpi
# 21554  student abroad talkative easygoe socialist uto...
# 22571  student mechanical kathisma techno car audi ci...
# 28392  ldtechnologist author use technology engage st...
# 24409  free world advocate student life tech junkie a...
#
#
# Cluster # 5
# 1726 (4%) users with valid description in this cluster
# [('work', 1783), ('game', 777), ('currently', 271), ('designer', 266), ('currently work', 233), ('developer', 202), ('artist', 196), ('make', 155), ('design', 118), ('studio', 116)]
#                                            clean_desc_en
# 5088    pen ink artist work indie game land eyas qfyn st
# 3478   game artist sl uninorthant ex aaa indie game w...
# 43711  game designer musician magician human currentl...
# 46237  two creative lukewicker iamwilf work part fact...
# 41985  happy engineer intellimob net umbraco azure si...
#
#
# Cluster # 6
# 515 (1%) users with valid description in this cluster
# [('try', 522), ('game', 125), ('make', 114), ('try make', 76), ('get', 72), ('play', 45), ('try get', 45), ('life', 43), ('thing', 42), ('video', 42)]
#                                            clean_desc_en
# 8633   guy try often possible make food game bud ui g...
# 120    illustration hobbyist predominantly traditiona...
# 10571  sell custom one vr headset sneaker shoe amanzo...
# 14918               artist try find path ultimate beauty
# 30196                   i be try youtuber valve bethesda
#
#
# Cluster # 7
# 7294 (15%) users with valid description in this cluster
# [('game', 8603), ('video', 1282), ('video game', 1151), ('developer', 970), ('play', 923), ('designer', 912), ('make', 871), ('game developer', 680), ('indie', 651), ('artist', 539)]
#                                          clean_desc_en
# 28271  youonlyliveonce competitive gamer fun play game
# 17313                                             game
# 10672                                  make game thing
# 4063                   treasure game profile sonicboom
# 12345                                      game artist
#
#
# Cluster # 8
# 824 (2%) users with valid description in this cluster
# [('creative', 849), ('director', 262), ('creative director', 212), ('designer', 159), ('design', 130), ('digital', 88), ('founder', 73), ('art', 70), ('studio', 53), ('artist', 46)]
#                                            clean_desc_en
# 2315   stop make sense creative strategy director spl...
# 21035  product designer deloittedigi au former fiver ...
# 6596   android dev creative app tech art currently bu...
# 22358  engine worldwide group cross discipline specia...
# 9899   talent acquisition manager akqa specialize thi...
#
#
# Cluster # 9
# 685 (1%) users with valid description in this cluster
# [('get', 728), ('follow', 71), ('youtube', 52), ('make', 43), ('life', 41), ('go', 39), ('start', 38), ('one', 36), ('gamer', 34), ('new', 32)]
#                                            clean_desc_en
# 40295  hi serch youtube nano slab click nano slab get...
# 30794                       journey get fit playing dota
# 22305    gamer get one soon play minecraft pe cod skyrim
# 27802  mechanical engineering study get pmp certifica...
# 20605                             life remote get change
#
#
# Cluster # 10
# 387 (1%) users with valid description in this cluster
# [('freelance', 391), ('designer', 146), ('illustrator', 77), ('artist', 64), ('developer', 42), ('freelance illustrator', 42), ('design', 39), ('graphic', 38), ('writer', 37), ('freelance designer', 36)]
#                                            clean_desc_en
# 2682                                 freelance cg artist
# 39671  illustration comic twitter shelley chen freela...
# 6194   synthwave turbo drive dna lounge indie gaming ...
# 46670            freelance ux ui designer working london
# 2587   freelance designer writer mixtape guru master ...
#
#
# Cluster # 11
# 1142 (2%) users with valid description in this cluster
# [('youtube', 1197), ('channel', 442), ('youtube channel', 370), ('subscribe', 232), ('check', 229), ('gaming', 188), ('video', 166), ('gamer', 150), ('follow', 136), ('check youtube', 130)]
#                                            clean_desc_en
# 26209  i be gamer awsome clan call xtremegamerkingz s...
# 10937  frequently tweet random youtube link feel free...
# 37179  youtube channel produce short film gaming vide...
# 19142                    youtube keep real teamacmc real
# 41792        mk tuber variety fc youtube channel jk qqhf
#
#
# CLUSTER K = 13
#
#
# Cluster # 0
# 33096 (69%) users with valid description in this cluster
# [('designer', 2492), ('gamer', 1700), ('artist', 1401), ('make', 1384), ('follow', 1277), ('developer', 1100), ('youtube', 1063), ('life', 949), ('work', 943), ('music', 927)]
#                                            clean_desc_en
# 9640             worldwide corporate aviation consultant
# 14084  life begin end comfort zone profile pic merryf...
# 32137  xcode start finish time wwdc wait keynote than...
# 9636   audience development lead proletariat inc make...
# 18166      youtuber pls follow tell guy upload new video
#
#
# Cluster # 1
# 8601 (18%) users with valid description in this cluster
# [('game', 10253), ('video', 1484), ('video game', 1335), ('developer', 1163), ('designer', 1086), ('make', 1075), ('play', 1053), ('game developer', 802), ('indie', 783), ('artist', 683)]
#                                            clean_desc_en
# 7145   artist designer cern headmediadesign game desi...
# 46539  official twitter account marvelous game within...
# 40726                                         video game
# 36476                     programmer game dev food eater
# 953    jamfuser winner group passionate student make ...
#
#
# Cluster # 2
# 784 (2%) users with valid description in this cluster
# [('tech', 812), ('design', 99), ('enthusiast', 87), ('music', 83), ('digital', 73), ('art', 68), ('lover', 67), ('geek', 59), ('tech enthusiast', 59), ('designer', 53)]
#                                            clean_desc_en
# 2425                                     design art tech
# 34655  network engineer computer scientist interested...
# 3570   software eng tech advocate usability strategis...
# 1061   founder cz dqh ib notchofriend host wzrpqgee m...
# 1580   brazilian computer science student python enth...
#
#
# Cluster # 3
# 508 (1%) users with valid description in this cluster
# [('instagram', 511), ('follow', 151), ('follow instagram', 75), ('youtube', 72), ('snapchat', 56), ('facebook', 34), ('designer', 31), ('artist', 30), ('gamer', 29), ('illustrator', 24)]
#                                            clean_desc_en
# 42514             follow instagram gaauxhm rc post daily
# 32407  gamer youtuber ihascupquake idol artist instag...
# 14804  reside mumbai hometown new delhi single bear d...
# 34751  follow instagram subscribe youtube michael bul...
# 18305  save heart one care instagram heart forget fac...
#
#
# Cluster # 4
# 292 (1%) users with valid description in this cluster
# [('draw', 304), ('thing', 35), ('art', 31), ('sometimes', 29), ('stuff', 26), ('artist', 25), ('illustrator', 18), ('music', 18), ('design', 17), ('lot', 17)]
#                                            clean_desc_en
# 2827   hi salty draw paint stuff suck social medium n...
# 6331   shy ace panro gamer soon system analyst kinda ...
# 40403  draw paint dm edit web comic_strip bunny rabbi...
# 21489  hello julian kind stuff draw fan art could tak...
# 12853          behold odd girl draw whatever catch fancy
#
#
# Cluster # 5
# ...
#                                            clean_desc_en
# 7822          technically game dev still learn space ace
# 34051  game dev tester junior game level designer foo...
# 35858  art director illustrator bafta breakthrough br...
# 22937  dev duo consist harley obium adamsingle work e...
# 8837                                   hobbyist game dev
#
#
# Cluster # 2
# 37803 (78%) users with valid description in this cluster
# [('game', 4749), ('designer', 2660), ('design', 2049), ('gamer', 1861), ('developer', 1817), ('follow', 1380), ('play', 1351), ('art', 1316), ('life', 1262), ('music', 1222)]
#                                            clean_desc_en
# 4382   code therefore guess exist machine learn ios g...
# 15052                            kuwasawa design jewelry
# 10923                                              bdcop
# 26944                                               teah
# 12715                                     game developer
#
#
# Cluster # 3
# 754 (2%) users with valid description in this cluster
# [('team', 819), ('game', 150), ('competitive', 77), ('look', 72), ('player', 67), ('gaming', 60), ('new', 55), ('call', 55), ('xbox', 55), ('us', 51)]
#                                            clean_desc_en
# 18098   free comp player xbox one look nice team dm talk
# 16931  new team that s gon na bring sick content thee...
# 25096             premi call duty team currently recruit
# 29467                                    owner team kuda
# 18796  bo league play player psn pexcefuil division p...
#
#
# Cluster # 4
# 942 (2%) users with valid description in this cluster
# [('game', 1203), ('designer', 997), ('game designer', 622), ('artist', 147), ('developer', 128), ('work', 109), ('make', 90), ('design', 75), ('founder', 68), ('programmer', 62)]
#                                            clean_desc_en
# 32493  game graphic designer octosoup founder avid ga...
# 3376            game designer redmassstudio therion game
# 10824  hi designer work first indie game piawkgame cr...
# 34260  game designer cook love intimacy game nichijou...
# 11412  game designer dev solo also rapscalco currentl...
#
#
# Cluster # 5
# 1385 (3%) users with valid description in this cluster
# [('game', 1634), ('video', 1446), ('video game', 1312), ('play', 303), ('play video', 201), ('play video game', 197), ('make', 148), ('music', 111), ('youtube', 91), ('developer', 79)]
#                                            clean_desc_en
# 5818   creative director wunthompsonperu video game b...
# 33909  average underage video game protagonist rp acc...
# 36553  build website mostly talk video game much good...
# 22038                           joshua video game friend
# 38362  game channel chicago illinoi new video every w...
#
#
# Cluster # 6
# 470 (1%) users with valid description in this cluster
# [('android', 482), ('game', 214), ('io', 188), ('io android', 127), ('developer', 112), ('app', 90), ('mobile', 68), ('android developer', 40), ('android io', 39), ('make', 35)]
#                                            clean_desc_en
# 4027   sarah hour streamer indie android game pokemon...
# 26492  application android base device produce hook s...
# 42672  trance enthusiast aspire producer dj swift ios...
# 40106         bathroombreak update available android ios
# 38767  indie game studio creator wobblybobby android ...
#
#
# Cluster # 7
# 2209 (5%) users with valid description in this cluster
# [('make', 2330), ('game', 895), ('make game', 302), ('thing', 251), ('video', 145), ('stuff', 135), ('design', 128), ('work', 126), ('music', 120), ('play', 120)]
#                                            clean_desc_en
# 1129                    make draw autistic staying hella
# 44474  scottish art director ireland make fun thing k...
# 2117   social humanitarian art design make game abt m...
# 30859   make thing sometimes computer undergrad stanford
# 5586         ouroborose stregawolf also tenlki make game
#
#
# Cluster # 8
# 551 (1%) users with valid description in this cluster
# [('channel', 590), ('youtube', 582), ('youtube channel', 490), ('check', 155), ('subscribe', 138), ('gaming', 103), ('game', 91), ('check youtube', 88), ('check youtube channel', 86), ('subscribe youtube', 67)]
#                                            clean_desc_en
# 12618     crapy youtube channel want make gaming channel
# 24555  hey guy noah speak go youtube channel noah upl...
# 27056       check youtube channel please subscribe thank
# 21665               twitt get hit gaming youtube channel
# 34148                                    youtube channel
#
#
# Cluster # 9
# 350 (1%) users with valid description in this cluster
# [('man', 368), ('game', 53), ('one', 30), ('family', 28), ('family man', 25), ('developer', 19), ('life', 18), ('fan', 18), ('one man', 17), ('gamer', 16)]
#                                            clean_desc_en
# 3185   ridiculous man responsible song summer sorry t...
# 18670                                           good man
# 11920  bear breed maker lemonade director komododigit...
# 5093   one man independentmagazine personal perspecti...
# 37534  founder geekautofficial multimediamouth direct...
#
#
# Cluster # 10
# 475 (1%) users with valid description in this cluster
# [('us', 522), ('follow', 128), ('game', 107), ('follow us', 105), ('join', 57), ('gaming', 56), ('youtube', 50), ('clan', 48), ('news', 35), ('join us', 34)]
#                                            clean_desc_en
# 37504  funny gaming video gtav nextgen xbox ps kcco g...
# 7630   eternal atypical influenced energy surround us...
# 45431                   follow us instagram artsyunicorn
# 31618  high quality high standard jersey design gfx d...
# 10104  help panpan defend wave encroach enemy escape ...
#
#
# Cluster # 11
# 1812 (4%) users with valid description in this cluster
# [('artist', 1899), ('game', 374), ('designer', 223), ('art', 204), ('illustrator', 182), ('work', 152), ('concept', 122), ('developer', 115), ('animator', 109), ('concept artist', 108)]
#                                            clean_desc_en
# 13449                     artist motion designer blender
# 28523  founder yarncorporation bigroomstudio hackport...
# 43568  technical artist vr specialist unreal engine u...
# 491     junior character artist animator stormcloud game
# 11641                   digital designer analogue artist
#
#
# Cluster # 12
# 512 (1%) users with valid description in this cluster
# [('name', 529), ('game', 76), ('play', 73), ('hi', 63), ('follow', 53), ('hi name', 47), ('i', 44), ('be', 44), ('i be', 44), ('hey', 41)]
#                                            clean_desc_en
# 3493   programmer back northwest pet name star war ch...
# 7834                             know name story hear do
# 6563   alfa alfa fantastic youth glutamine music kuro...
# 31399  name dustin single extreme sport paintball fav...
# 23618                   name sean one life one live best
#
#
# Cluster # 13
# 234 (0%) users with valid description in this cluster
# [('company', 241), ('game', 74), ('design', 31), ('mobile', 27), ('development', 26), ('game company', 23), ('work', 22), ('base', 18), ('service', 17), ('product', 17)]
#                                            clean_desc_en
# 39764  founder oonihq world pizza oven company oft fi...
# 34914           owner graphic designer hydra tie company
# 18444  indie company develop mob game software first ...
# 31894  build company zero traction amazing entreprene...
# 9668   smart mobilegame appdev whitetilesgame musical...
#
#
# CLUSTER K = 15
#
#
# Cluster # 0
# 31234 (65%) users with valid description in this cluster
# [('gamer', 1389), ('follow', 1336), ('design', 1333), ('artist', 1226), ('make', 1157), ('developer', 1058), ('gaming', 1047), ('youtube', 1024), ('music', 917), ('work', 867)]
#                                            clean_desc_en
# 28252  new youtube channel kingsofdisastergaming go c...
# 17586                                       indiegamedev
# 21482                                           year old
# 33181  japanese antique art specialist itinerant doodler
# 44958                          app store apple making go
#
#
# Cluster # 1
# 1453 (3%) users with valid description in this cluster
# [('life', 1529), ('game', 230), ('live', 183), ('live life', 96), ('make', 93), ('gamer', 87), ('music', 82), ('thing', 78), ('good', 67), ('enjoy', 67)]
#                                            clean_desc_en
# 7626   multidisciplinary mind art design technology p...
# 45486  international luxury wedding cellist session c...
# 45364           important thing life learn give let come
# 22850                                    life river flow
# 14284  guess say chill chick would rather watch netfl...
#
#
# Cluster # 2
# 528 (1%) users with valid description in this cluster
# [('know', 560), ('game', 87), ('guy', 43), ('want', 40), ('make', 37), ('also', 37), ('thing', 36), ('follow', 35), ('let', 35), ('get', 35)]
#                                            clean_desc_en
# 32082  dangerous business go door step onto road keep...
# 20294  hello name lucas probably already know youtube...
# 225                 know occasionally venture slipstream
# 897    everything ahead us totally unknown guarantee ...
# 27782  hoper friend enthusiast movie artbook maker ms...
#
#
# Cluster # 3
# 797 (2%) users with valid description in this cluster
# [('guy', 841), ('game', 189), ('hey', 156), ('hey guy', 142), ('youtube', 100), ('video', 89), ('follow', 84), ('channel', 83), ('play', 77), ('make', 76)]
#                                            clean_desc_en
# 22583    hey guy mine craft pvp pro wan na play tweet sg
# 24805  hey guy i be youtuber go subscribe foxytheplay...
# 12346  hey guy welcome back game locate crestwood lan...
# 42155                              two guy try make game
# 35965  welcome back everyone undutree trio funny guy ...
#
#
# Cluster # 4
# 287 (1%) users with valid description in this cluster
# [('girl', 297), ('game', 48), ('gamer', 32), ('love', 19), ('video', 18), ('artist', 17), ('thing', 17), ('make', 15), ('world', 15), ('good', 15)]
#                                            clean_desc_en
# 36893                         take good girl friend ever
# 12853          behold odd girl draw whatever catch fancy
# 4964   girlsbehindthegame campaign runawayplay want e...
# 26740                    dreamer girl live fantasy world
# 7027   tran girl game dev modeler link website afford...
#
#
# Cluster # 5
# 1287 (3%) users with valid description in this cluster
# [('thing', 1357), ('game', 313), ('make', 243), ('designer', 139), ('design', 119), ('make thing', 114), ('lover', 85), ('work', 82), ('artist', 80), ('art', 74)]
#                                            clean_desc_en
# 6460                                          thing code
# 11543                                              thing
# 45696  program art blend like make interactive thing ...
# 44059  write thing computer understand married getmec...
# 8721                                         build thing
#
#
# Cluster # 6
# 7843 (16%) users with valid description in this cluster
# [('game', 9370), ('video', 1298), ('video game', 1171), ('developer', 1109), ('designer', 1027), ('make', 963), ('play', 912), ('game developer', 770), ('indie', 733), ('artist', 642)]
#                                            clean_desc_en
# 24134  gamer video game blackle destiny gta ramdon tw...
# 36579  perpetual scholar lover ellipsis psychology re...
# 12586  former naughty dog lead game designer professo...
# 5856   designer artist photographer streamer theorist...
# 22219                                      game yeah fun
#
#
# Cluster # 7
# 409 (1%) users with valid description in this cluster
# [('ps', 450), ('play', 85), ('xbox', 82), ('clan', 79), ('gamer', 76), ('add', 57), ('follow', 45), ('gaming', 42), ('team', 37), ('one', 36)]
#                                            clean_desc_en
# 30575  elm sos ag marvelteam batman arrow theflash ed...
# 28207  mvp baseball ps update current mid actively ac...
# 30456                               ps gamer live stream
# 22954                                            ps team
# 19257  new youtuber xbox ps belive acheive man win le...
#
#
# Cluster # 8
# 2769 (6%) users with valid description in this cluster
# [('designer', 2857), ('graphic', 467), ('ux', 409), ('graphic designer', 396), ('product', 307), ('design', 284), ('illustrator', 281), ('product designer', 249), ('ui', 228), ('ux designer', 228)]
#                                            clean_desc_en
# 3647                               ux designer leet tech
# 16436                                    designer planet
# 44680  human overall product designer facebook former...
# 12941  surrey bear motion graphic designer love earl ...
# 10920              art director ux ui designer hcsf umbz
#
#
# Cluster # 9
# 232 (0%) users with valid description in this cluster
# [('london', 245), ('base', 54), ('design', 43), ('digital', 32), ('director', 32), ('base london', 28), ('art', 25), ('creative', 24), ('london base', 23), ('artist', 18)]
#                                            clean_desc_en
# 3628   architect collcoll work eva jiricna architect ...
# 11084  award win zero emission network help business ...
# 2661   official page rauli rd art gizmo riihim ki new...
# 40556  hello design facebook previously lead design m...
# 7568   unique private member club heart covent garden...
#
#
# Cluster # 10
# 192 (0%) users with valid description in this cluster
# [('youtube', 205), ('gamer', 204), ('channel', 62), ('youtube channel', 46), ('subscribe', 34), ('check', 34), ('game', 32), ('play', 31), ('youtube gamer', 26), ('gamer youtube', 23)]
#                                            clean_desc_en
# 34949  hi everyone i be gamer strid i be want streame...
# 22562  hello everybody name andre baker young youtube...
# 38156            gamer youtuber subscribe youtube ddhxhb
# 7448   youtube gamer enjoy broad spectrum game genera...
# 35694  ux designer youtube aquarium nerd patient game...
#
#
# Cluster # 11
# 671 (1%) users with valid description in this cluster
# [('director', 694), ('creative', 215), ('creative director', 178), ('art', 139), ('design', 114), ('art director', 108), ('founder', 88), ('digital', 44), ('writer', 41), ('design director', 38)]
#                                            clean_desc_en
# 7134              chief executive director brave perfect
# 37204  art director artist one third paper house melb...
# 47607                                     actor director
# 4465   dreamer father husband fan snow rock tech mufc...
# 46142        technical director leagueofgeek armellogame
#
#
# Cluster # 12
# 251 (1%) users with valid description in this cluster
# [('social', 262), ('medium', 125), ('social medium', 114), ('marketing', 23), ('design', 20), ('digital', 17), ('music', 17), ('manager', 16), ('tweet', 15), ('gamer', 14)]
#                                            clean_desc_en
# 4551   social medium creative consultancy individual ...
# 16059  sporadically tweet generally suck social messa...
# 12053  social medium manager blogger rdt cayzd introv...
# 42902                          anti social social medium
# 29687  twitter make wow integrate twitter literally w...
#
#
# Cluster # 13
# 98 (0%) users with valid description in this cluster
# [('passion', 98), ('music', 14), ('digital', 9), ('design', 9), ('work', 8), ('technology', 7), ('creative', 7), ('art', 6), ('freelance', 6), ('tech', 5)]
#                                            clean_desc_en
# 18534  freelance illustrator strong passion robot exi...
# 24101  master ict base educational design teacher pas...
# 6085   independent artist business owner youtuber pas...
# 40589  gamedev company slovakia passion joy player pl...
# 40393                      shoot punch lan champ passion
#
#
# Cluster # 14
# 173 (0%) users with valid description in this cluster
# [('would', 182), ('i', 46), ('i would', 42), ('follow', 17), ('youtube', 15), ('psn', 12), ('xbox', 12), ('join', 12), ('get', 11), ('make', 11)]
#                                            clean_desc_en
# 18932  absolutely supernatural doctor sherlock also w...
# 34169                                would without music
# 4304   welcome asterra puzzle curse riddle lead place...
# 40521  good mobile app review tech news site online f...
# 6172   would inquire commission please email edgrace ...

# %% [markdown]
# Surveying the cluster results, common themes consistently arise. Gaming is clearly the most common interest among @ustwogames Twitter followers. Professions associated with the industry are also fairly popular, e.g. game designers, graphic designers, and UX designers. A few notable examples include the following:
#  - *K=8, Cluster #3*: video game enthusiasts that stream on YouTube
#  - *K=9, Cluster #8*: game developers, particularly indie studios
#  - *K=10, Cluster #9*: creatives, e.g. graphic designers, artists, illustrators.
#
# Of course, not all clusters are informative. For example, *K=6, Cluster #4* is primarily characterized by descriptions that include the word "hi".

# %% [markdown]
# #### DBSCAN clustering <a name='dbscan'></a>
#
# DBSCAN (density-based spatial clustering of applications with noise) is a density-based clustering algorithim. Unlike K-modes, which will force each data point to be assigned to a cluster, DBSCAN will mark data in low-density regions as outliers.
#
# Descriptions were vectorized by normalized term frequency.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN

DB_NAME = 'customer-segmentation-clean'
TAB_NAME = 'ustwo_followers_clean'

# Pull processed data from SQLite DB
e = sa.create_engine('sqlite:///./data/processed/' + DB_NAME + '.sqlite')

#SQL query includes a WHERE statement that filters out NA values and empty strings
query = 'SELECT id, clean_desc_en FROM ' + TAB_NAME + ' WHERE clean_desc_en != \'\''
users = pd.read_sql_query(query, e)
N_DESC = 10
N_KEYWORDS = 10

tf = TfidfVectorizer(use_idf=False)
tf_matrix = tf.fit_transform(users['clean_desc_en']) #tf is normalized as opposed to cv

dbscan = DBSCAN(eps=1.2, min_samples=1000)

y_pred = dbscan.fit_predict(tf_matrix)
users['cluster'] = dbscan.labels_

# Push processed data into SQLite DB. Profiles with non-English or empty descriptions were dropped
DB_RESULTS_NAME = 'customer-segmentation-cluster'
TAB_RESULTS_NAME = 'ustwo_followers_dbscan'
e = sa.create_engine('sqlite:///./models/' + DB_RESULTS_NAME + '.sqlite')
users.to_sql(TAB_RESULTS_NAME, e, if_exists='replace')

# Print results
n_clusters = len(np.unique(dbscan.labels_))
clust_rng = (-1, n_clusters-1) # offset by -1 since DBSCAN's first cluster is #-1
print_cluster_results(df=users, col_clust='cluster', col_list=['clean_desc_en'], clust_rng=clust_rng)
# Out:
# Cluster # -1
# 14653 (30%) users with valid description in this cluster
# [('world', 391), ('founder', 381), ('work', 380), ('tweet', 337), ('get', 328), ('new', 327), ('fan', 316), ('tech', 315), ('team', 303), ('good', 299)]
#                                            clean_desc_en
# 2620                      pok mon go player shiny hunter
# 22901  formerly know alias cl ud twitch mod launder boxr
# 36567  player listener griller writer drinker travele...
# 46186  partner equalexpert instructor snowcentre drin...
# 15360  find tutor make easy stutor list tutor right a...
#
#
# Cluster # 0
# 33571 (70%) users with valid description in this cluster
# [('game', 10230), ('designer', 4115), ('make', 2613), ('developer', 2461), ('design', 2353), ('gamer', 2216), ('artist', 2185), ('video', 2092), ('play', 1971), ('follow', 1763)]
#                                            clean_desc_en
# 1203   indie game studio base london building trading...
# 31796                          designer zaraguza digital
# 764    creator game designer speaker founder terebima...
# 5205   game designer playsidestudio previously lead d...
# 12152  youtube gamer subscribe yt channel turn notifi...

# %% [markdown]
# DBSCAN determined that 70% of the cleaned Twitter descriptions were similiar enough to form a distint cluster (label = 0), while the remaining 30% were classified as outliers (label = -1). None of the top ten vocabulary words were shared between the Cluster #0 and "Cluster" #-1, suggesting good separation of the classes.
#
# The results corroborate those found via K-modes clustering. Based on the top vocabulary words of Cluster #0, a significant portion of USTWO Games Twitter followers are interested in gaming. This population seems to include video game fans, as well as professional or hobbyist creators: roughly of the top ten vocabulary words are associated with video game design, art, and development.
#
# ### Clustering users based on their friends <a name='friendcluster'></a>
#
# Clustering based on profile description has allowed us to identify useful customer segments: gamers, video game creators, developers, and Twitch/YouTube streamers. However, this approach has few a limitations. Profile descriptions are not mandatory, and many Twitter users choose to leave the field blank. Profiles that do contain a description may not contain relevant or useful information. Finally, this approach is biased towards professionals, or individuals with products or services to sell or advertise: these users have an incentive to create a profile description that is complete, informative, and accurate.
#
# Another approach to customer segmentation is by clustering Twitter users based on the accounts that they follow (termed 'friends'). Presumably, users will only follow friends whose content they want to see: a user's friends are a reflection of their interests.
#
# The user ID of the friends of @ustwogames followers were collected. K-modes categorical clustering was performed to determine if users could be clustered based on the accounts they followed.
#
# Due to the rate limitations of the Twitter API, collecting the friend IDs of every USTO Games follower would be excessively time consuming. Stratified sampling based on the DBSCAN clustering results was performed to reduce the sample size to 10% (12592 users).

# %%
# Get profiles that were clustered
DB_NAME = 'customer-segmentation-cluster'
TAB_NAME = 'ustwo_followers_dbscan'
e = sa.create_engine('sqlite:///./models/' + DB_NAME + '.sqlite')
query = 'SELECT id, clean_desc_en, cluster FROM ' + TAB_NAME
users_clustered = pd.read_sql_query(query, e)

# Get profiles that were not eligible for clustering (empty or not English)
DB_NAME = 'customer-segmentation-clean'
TAB_NAME = 'ustwo_followers_clean'
e = sa.create_engine('sqlite:///./data/processed/' + DB_NAME + '.sqlite')
query = 'SELECT id, clean_desc_en FROM ' + TAB_NAME + ' WHERE clean_desc_en == \'\' OR clean_desc_en IS NULL'
users_empty = pd.read_sql_query(query, e)
users_empty['cluster'] = -2 # create new 'cluster' assignment, to which all empty profiles are assigned

# Combine dataframes
users = users_clustered.append(users_empty, ignore_index=True)

# Stratified sampling profiles by cluster assignment, pushing results to database
TAB_SAMPLES_NAME = 'ustwo_followers_sampled'
sampled_users = users.groupby('cluster').apply(lambda x: x.sample(frac=0.1, random_state=42))
sampled_users.reset_index(drop=True).to_sql(TAB_SAMPLES_NAME, e, if_exists='replace')

# %% [markdown]
# The Twitter API allows scraping of the IDs of accounts a given user follows. However, if a screenname or additional profile information is desired, that would require a separate request.
#
# Scraping the friend IDs of the sampled @ustwogames followers yielded a table entitled *ustwo_sampled_friends_ids*. The two column table consisted of a user ID and a friend ID, i.e. one user-friend pair for each account a given user followed.
#
# Since scraping the profile information of every account followed by @ustwo games followers would be resource-intensive and minimally useful, only the most common friend IDs were scraped for their profile information (specifically friend IDs that had at least 75 @ustwo followers following it). This generated a table entitled *ustwo_sampled_fol_friends.*
#
# In order to continue with K-modes, it was necessary to generate a two-column table consisting of a user ID and a list containing the screen names of every account that user followed.
#
# This table was generated using the SQL query written below. Step-by-step, the query performs the following functions:
# 1. Filter out redundant user-friend ID pairs and exclude the friend ID @ustwogames, since all users follow that account
# 2. Filter out friend IDs that have less than 75 users following that account, since very unpopular accounts will not be relevant when clustering
# 3. Join the resulting subtable containing the filtered user and friend IDs with another table (*ustwo_sampled_fol_friends*) that contains the screennames associated with a given friend ID
# 4. That resulting subtable was grouped by user ID, generating a second column consisting of concatenated screenames of friends

# %%
DB_NAME = 'customer-segmentation'
e = sa.create_engine('sqlite:///./data/interim/' + DB_NAME + '.sqlite')

query = '''
-- returns a list of friends (by screen name) that are followed by a given user
SELECT 
	user_id, GROUP_CONCAT(screen_name, " ") AS friends_list
FROM (
	-- only interested in friends that are followed by at least 75 users
	SELECT 
		user_id, friend_id
	FROM 
		ustwo_sampled_friends_ids
	WHERE
		friend_id
	IN (
		SELECT 
			friend_id
		FROM (
			-- filter out redundant user-friend id pairs
			SELECT DISTINCT
				user_id, friend_id
			FROM 
				ustwo_sampled_friends_ids
			-- filter out USTWO user id, since it will have no value in clustering since everyone follows the account
			WHERE 
				friend_id != 899902687
		)
		GROUP BY 
			friend_id
		HAVING
			COUNT(user_id) >= 75
	)
) AS tab
LEFT JOIN
	ustwo_sampled_fol_friends
ON 
	tab.friend_id == ustwo_sampled_fol_friends.id
GROUP BY 
	user_id
'''

users = pd.read_sql_query(query, e)

# %% [markdown]
# An example of the resulting output is shown below.

# %%
users.sample(n=5, random_state=42)
# Out:
#             user_id                                       friends_list
# 3128   1.394420e+09  briecode quasimondo lorenschmidt jesseringrose...
# 11176  4.751143e+09  ThomasSanders shenanigansen vaughnpinpin paper...
# 200    1.425125e+07  Kotaku rockpapershot OnePerfectShot FinjiCo Wh...
# 9480   3.285014e+09  Roblox Taymastar levine pgbiz RockstarGames gi...
# 8235   3.178516e+09  Twitch Pentadact TheEllenShow AnnaKendrick47 f...

# %% [markdown]
# K-modes clustering can now be performed. As before, no optimal K value was assumed a priori, so a range of (2 to 4) was tested.

# %%
cv = CountVectorizer(min_df=1, max_df=1.0, binary=True)
cat_matrix = cv.fit_transform(users['friends_list'])

NUM_CLUSTERS_RNG = 5

# Connect to DB where cluster results are to be saved
DB_RESULTS_NAME = 'customer-segmentation-cluster'
e = sa.create_engine('sqlite:///./models/' + DB_RESULTS_NAME + '.sqlite')
TAB_RESULTS_PREFIX = 'ustwo_fol_friends_k_'

for n_clusters in range(2, NUM_CLUSTERS_RNG):
    kmod = KModes(n_clusters=n_clusters, init='Huang', random_state=42, n_jobs=-1)
    y_pred = kmod.fit_predict(cat_matrix.toarray())
    users['cluster'] = kmod.labels_
    tab_name = TAB_RESULTS_PREFIX + str(n_clusters)
    users.to_sql(tab_name, e, if_exists='replace')

# %%
DB_NAME = 'customer-segmentation-cluster'
e = sa.create_engine('sqlite:///./models/' + DB_NAME + '.sqlite')

for n_clusters in range(2, NUM_CLUSTERS_RNG):

    TAB_NAME = 'ustwo_fol_friends_k_' + str(n_clusters)
    query = 'SELECT user_id, friends_list, cluster FROM ' + TAB_NAME
    users = pd.read_sql_query(query, e)

    print('CLUSTER K = ' + str(n_clusters))
    print('\n')
    print_cluster_results(df=users, col_clust='cluster', col_list=['friends_list'],
                          clust_rng=(0,n_clusters), n_keywords=50, n_desc=0)
# Out:
# CLUSTER K = 2
#
#
# Cluster # 0
# 6292 (53%) users with valid description in this cluster
# [('RockstarGames', 5627), ('Ubisoft', 5593), ('PlayStation', 5568), ('Xbox', 5567), ('IGN', 5567), ('Kotaku', 5552), ('GameSpot', 5544), ('Twitch', 5535), ('TimOfLegend', 5533), ('giantbomb', 5532), ('engadgetgaming', 5529), ('HIDEO_KOJIMA_EN', 5507), ('NintendoAmerica', 5500), ('notch', 5494), ('Polygon', 5489), ('GamesRadar', 5488), ('gamasutra', 5488), ('SupergiantGames', 5483), ('PocketGamer', 5481), ('patrickklepek', 5476), ('fullbright', 5472), ('ID_AA_Carmack', 5465), ('telltalegames', 5460), ('2K', 5449), ('EAMobile', 5435), ('pgbiz', 5423), ('GooglePlay', 5422), ('GamesBeat', 5422), ('AppStore', 5404), ('leighalexander', 5401), ('acarboni', 5394), ('Quinns108', 5392), ('Pentadact', 5392), ('WH1SKI', 5390), ('levine', 5382), ('popcap', 5352), ('bfod', 5349), ('MaxTemkin', 5282), ('tinybop', 4542), ('tha_rami', 3868), ('brandonnn', 3825), ('chrisremo', 3816), ('br', 3778), ('stephentotilo', 3777), ('toucharcade', 3773), ('helvetica', 3768), ('ibogost', 3762), ('kirkhamilton', 3726), ('avantgame', 3716), ('femfreq', 3702)]
#
#
# Cluster # 1
# 5481 (47%) users with valid description in this cluster
# [('BarackObama', 1770), ('elonmusk', 1639), ('PlayStation', 1479), ('NASA', 1337), ('RockstarGames', 1326), ('BillGates', 1220), ('Google', 1206), ('Ubisoft', 1193), ('steam_games', 1177), ('NintendoAmerica', 1158), ('Twitter', 1154), ('IGN', 1145), ('Xbox', 1140), ('YouTube', 1137), ('Polygon', 1036), ('HIDEO_KOJIMA_EN', 1033), ('AppStore', 1026), ('Twitch', 977), ('WIRED', 958), ('GooglePlay', 952), ('Kotaku', 943), ('tim_cook', 933), ('neiltyson', 930), ('gamasutra', 924), ('SpaceX', 911), ('GameSpot', 857), ('TimOfLegend', 851), ('notch', 835), ('nytimes', 828), ('TechCrunch', 826), ('SupergiantGames', 818), ('TheEllenShow', 816), ('Android', 814), ('Snowden', 808), ('tha_rami', 801), ('jimmyfallon', 797), ('verge', 796), ('instagram', 778), ('telltalegames', 771), ('unity3d', 767), ('POTUS44', 765), ('EA', 748), ('Naughty_Dog', 740), ('ID_AA_Carmack', 738), ('Microsoft', 716), ('RobertDowneyJr', 693), ('Dropbox', 693), ('EmmaWatson', 691), ('jk_rowling', 684), ('TEDTalks', 675)]
#
#
# CLUSTER K = 3
#
#
# Cluster # 0
# 5253 (45%) users with valid description in this cluster
# [('BarackObama', 1708), ('elonmusk', 1590), ('NASA', 1299), ('PlayStation', 1276), ('BillGates', 1170), ('Google', 1155), ('RockstarGames', 1132), ('Twitter', 1112), ('steam_games', 1073), ('YouTube', 1072), ('Ubisoft', 998), ('NintendoAmerica', 979), ('IGN', 953), ('Xbox', 946), ('WIRED', 914), ('tim_cook', 910), ('neiltyson', 898), ('HIDEO_KOJIMA_EN', 889), ('AppStore', 886), ('SpaceX', 883), ('Polygon', 860), ('GooglePlay', 813), ('nytimes', 800), ('Snowden', 795), ('Twitch', 791), ('TechCrunch', 789), ('Kotaku', 788), ('verge', 774), ('TheEllenShow', 769), ('Android', 769), ('gamasutra', 758), ('instagram', 752), ('tha_rami', 749), ('POTUS44', 742), ('jimmyfallon', 735), ('TimOfLegend', 725), ('notch', 718), ('unity3d', 711), ('Dropbox', 674), ('GameSpot', 671), ('jk_rowling', 670), ('Microsoft', 665), ('EmmaWatson', 664), ('EA', 662), ('Naughty_Dog', 658), ('RobertDowneyJr', 657), ('Medium', 657), ('SupergiantGames', 654), ('ustwo', 652), ('TEDTalks', 652)]
#
#
# Cluster # 1
# 3723 (32%) users with valid description in this cluster
# [('RockstarGames', 3192), ('Ubisoft', 3176), ('PlayStation', 3172), ('Xbox', 3162), ('GameSpot', 3138), ('Twitch', 3128), ('IGN', 3127), ('NintendoAmerica', 3100), ('engadgetgaming', 3093), ('Kotaku', 3088), ('GamesRadar', 3081), ('Polygon', 3070), ('gamasutra', 3066), ('giantbomb', 3062), ('HIDEO_KOJIMA_EN', 3048), ('PocketGamer', 3047), ('2K', 3045), ('SupergiantGames', 3038), ('telltalegames', 3038), ('TimOfLegend', 3033), ('EAMobile', 3013), ('notch', 3013), ('AppStore', 3001), ('GooglePlay', 2998), ('ID_AA_Carmack', 2986), ('GamesBeat', 2977), ('pgbiz', 2943), ('popcap', 2940), ('patrickklepek', 2927), ('fullbright', 2926), ('levine', 2902), ('Quinns108', 2902), ('Pentadact', 2877), ('WH1SKI', 2862), ('leighalexander', 2861), ('acarboni', 2855), ('bfod', 2841), ('MaxTemkin', 2755), ('tinybop', 2063), ('tha_rami', 1252), ('brandonnn', 1186), ('toucharcade', 1176), ('chrisremo', 1152), ('stephentotilo', 1142), ('br', 1141), ('ibogost', 1123), ('femfreq', 1107), ('helvetica', 1104), ('kirkhamilton', 1082), ('avantgame', 1072)]
#
#
# Cluster # 2
# 2797 (24%) users with valid description in this cluster
# [('chrisremo', 2682), ('helvetica', 2682), ('br', 2672), ('tha_rami', 2668), ('kirkhamilton', 2666), ('stephentotilo', 2665), ('ibogost', 2661), ('brandonnn', 2658), ('idlethumbs', 2654), ('amy_hennig', 2651), ('avantgame', 2650), ('flantz', 2645), ('toucharcade', 2644), ('IGN', 2632), ('RockstarGames', 2629), ('BlendoGames', 2629), ('femfreq', 2628), ('TimOfLegend', 2626), ('patrickklepek', 2626), ('Kotaku', 2619), ('fullbright', 2618), ('Ubisoft', 2612), ('SupergiantGames', 2609), ('giantbomb', 2605), ('HIDEO_KOJIMA_EN', 2603), ('engadgetgaming', 2603), ('Xbox', 2599), ('PlayStation', 2599), ('geektreschic', 2599), ('notch', 2598), ('thisgame', 2596), ('Polygon', 2595), ('Pentadact', 2594), ('WH1SKI', 2593), ('Twitch', 2593), ('telltalegames', 2592), ('GameSpot', 2592), ('leighalexander', 2590), ('acarboni', 2588), ('gamasutra', 2588), ('pgbiz', 2587), ('ID_AA_Carmack', 2584), ('GamesBeat', 2582), ('PocketGamer', 2580), ('NintendoAmerica', 2579), ('MaxTemkin', 2576), ('GamesRadar', 2575), ('bfod', 2572), ('levine', 2569), ('2K', 2566)]
#
#
# CLUSTER K = 4
#
#
# Cluster # 0
# 1854 (16%) users with valid description in this cluster
# [('Polygon', 1842), ('patrickklepek', 1842), ('fullbright', 1839), ('TimOfLegend', 1839), ('telltalegames', 1838), ('stephentotilo', 1838), ('tha_rami', 1838), ('ID_AA_Carmack', 1838), ('br', 1838), ('chrisremo', 1837), ('therealcliffyb', 1837), ('helvetica', 1837), ('ibogost', 1837), ('gamasutra', 1837), ('bethesda', 1836), ('engadgetgaming', 1836), ('levine', 1835), ('Kotaku', 1833), ('giantbomb', 1833), ('bfod', 1833), ('SupergiantGames', 1831), ('kirkhamilton', 1831), ('amy_hennig', 1831), ('HIDEO_KOJIMA_EN', 1830), ('geoffkeighley', 1830), ('brandonnn', 1830), ('IGN', 1830), ('leighalexander', 1827), ('Pentadact', 1826), ('yosp', 1825), ('RockstarGames', 1825), ('WH1SKI', 1825), ('Ubisoft', 1824), ('GamesRadar', 1824), ('jeffgerstmann', 1823), ('flantz', 1823), ('BlendoGames', 1823), ('notch', 1822), ('femfreq', 1821), ('idlethumbs', 1821), ('avantgame', 1821), ('GameSpot', 1819), ('pgbiz', 1819), ('majornelson', 1818), ('UnburntWitch', 1818), ('MaxTemkin', 1817), ('NintendoAmerica', 1816), ('toucharcade', 1816), ('GamesBeat', 1816), ('Quinns108', 1815)]
#
#
# Cluster # 1
# 2304 (20%) users with valid description in this cluster
# [('RockstarGames', 1779), ('Xbox', 1742), ('chrisremo', 1740), ('PlayStation', 1740), ('IGN', 1739), ('Ubisoft', 1737), ('Kotaku', 1727), ('tha_rami', 1717), ('Twitch', 1716), ('patrickklepek', 1711), ('br', 1709), ('GameSpot', 1709), ('giantbomb', 1706), ('avantgame', 1701), ('helvetica', 1701), ('ibogost', 1698), ('brandonnn', 1695), ('TimOfLegend', 1695), ('stephentotilo', 1692), ('HIDEO_KOJIMA_EN', 1691), ('leighalexander', 1688), ('tinybop', 1687), ('notch', 1683), ('engadgetgaming', 1682), ('NintendoAmerica', 1681), ('idlethumbs', 1681), ('PocketGamer', 1679), ('toucharcade', 1677), ('flantz', 1674), ('pgbiz', 1673), ('kirkhamilton', 1673), ('femfreq', 1670), ('GamesRadar', 1669), ('acarboni', 1668), ('gamasutra', 1662), ('fullbright', 1661), ('2K', 1657), ('GooglePlay', 1657), ('SupergiantGames', 1652), ('Pentadact', 1649), ('EAMobile', 1648), ('Polygon', 1639), ('Quinns108', 1637), ('WH1SKI', 1636), ('AppStore', 1629), ('bfod', 1626), ('telltalegames', 1624), ('ID_AA_Carmack', 1623), ('MaxTemkin', 1621), ('GamesBeat', 1619)]
#
#
# Cluster # 2
# 5237 (44%) users with valid description in this cluster
# [('BarackObama', 1701), ('elonmusk', 1588), ('NASA', 1299), ('PlayStation', 1278), ('BillGates', 1168), ('Google', 1154), ('RockstarGames', 1124), ('Twitter', 1111), ('YouTube', 1072), ('steam_games', 1067), ('Ubisoft', 989), ('NintendoAmerica', 974), ('IGN', 952), ('Xbox', 945), ('WIRED', 914), ('tim_cook', 910), ('neiltyson', 896), ('AppStore', 886), ('SpaceX', 883), ('HIDEO_KOJIMA_EN', 881), ('Polygon', 850), ('GooglePlay', 806), ('nytimes', 800), ('Snowden', 795), ('Twitch', 793), ('TechCrunch', 790), ('verge', 773), ('Android', 770), ('Kotaku', 769), ('TheEllenShow', 755), ('gamasutra', 753), ('instagram', 751), ('POTUS44', 742), ('tha_rami', 728), ('jimmyfallon', 728), ('TimOfLegend', 712), ('unity3d', 710), ('notch', 708), ('Dropbox', 673), ('jk_rowling', 670), ('GameSpot', 665), ('EmmaWatson', 665), ('Microsoft', 665), ('RobertDowneyJr', 657), ('EA', 657), ('Medium', 656), ('Naughty_Dog', 656), ('SupergiantGames', 655), ('ustwo', 652), ('TEDTalks', 651)]
#
#
# Cluster # 3
# 2378 (20%) users with valid description in this cluster
# [('Ubisoft', 2236), ('RockstarGames', 2225), ('Xbox', 2222), ('PlayStation', 2219), ('GameSpot', 2208), ('Twitch', 2205), ('Polygon', 2194), ('IGN', 2191), ('NintendoAmerica', 2187), ('engadgetgaming', 2185), ('telltalegames', 2177), ('GamesRadar', 2167), ('Kotaku', 2166), ('SupergiantGames', 2163), ('gamasutra', 2160), ('2K', 2146), ('TimOfLegend', 2138), ('HIDEO_KOJIMA_EN', 2138), ('giantbomb', 2136), ('PocketGamer', 2135), ('GamesBeat', 2124), ('ID_AA_Carmack', 2117), ('GooglePlay', 2116), ('notch', 2116), ('EAMobile', 2115), ('popcap', 2109), ('AppStore', 2108), ('fullbright', 2058), ('levine', 2056), ('pgbiz', 2044), ('patrickklepek', 2013), ('Quinns108', 2012), ('WH1SKI', 2004), ('Pentadact', 1996), ('acarboni', 1972), ('bfod', 1964), ('leighalexander', 1948), ('MaxTemkin', 1899), ('tinybop', 1099), ('steam_games', 489), ('EA', 453), ('YouTube', 435), ('jimmyfallon', 405), ('TheEllenShow', 403), ('BarackObama', 399), ('tha_rami', 386), ('gameinformer', 369), ('toucharcade', 345), ('brandonnn', 342), ('CallofDuty', 308)]
#
#
# CLUSTER K = 5
#
#
# Cluster # 0
# 459 (4%) users with valid description in this cluster
# [('Ubisoft', 429), ('RockstarGames', 426), ('PlayStation', 425), ('steam_games', 413), ('Naughty_Dog', 403), ('IGN', 393), ('EA', 383), ('bethesda', 376), ('Kotaku', 374), ('Xbox', 370), ('E3', 370), ('gameinformer', 363), ('insomniacgames', 362), ('Polygon', 361), ('GameSpot', 348), ('NintendoAmerica', 348), ('EpicGames', 346), ('HIDEO_KOJIMA_EN', 342), ('bioware', 335), ('telltalegames', 331), ('SEGA', 329), ('gamasutra', 324), ('BethesdaStudios', 307), ('Twitch', 301), ('2K', 295), ('Konami', 292), ('GearboxOfficial', 282), ('engadgetgaming', 273), ('humble', 269), ('Bungie', 267), ('unity3d', 266), ('pcgamer', 264), ('Official_GDC', 262), ('GhostStoryGames', 259), ('TimOfLegend', 258), ('DoubleFine', 256), ('SupergiantGames', 255), ('GameTrailers', 246), ('UnrealEngine', 244), ('GamesRadar', 243), ('thatgamecompany', 224), ('Jonathan_Blow', 218), ('indiegamescom', 218), ('Sony', 217), ('Microsoft', 216), ('SuckerPunchProd', 211), ('idSoftware', 209), ('hellogames', 209), ('eurogamer', 209), ('YouTube', 208)]
#
#
# Cluster # 1
# 1818 (15%) users with valid description in this cluster
# [('patrickklepek', 1815), ('stephentotilo', 1811), ('chrisremo', 1811), ('br', 1809), ('bfod', 1809), ('helvetica', 1808), ('tha_rami', 1807), ('kirkhamilton', 1807), ('ID_AA_Carmack', 1807), ('ibogost', 1807), ('fullbright', 1806), ('geoffkeighley', 1806), ('bethesda', 1806), ('TimOfLegend', 1806), ('therealcliffyb', 1806), ('giantbomb', 1806), ('idlethumbs', 1805), ('Polygon', 1805), ('levine', 1805), ('WH1SKI', 1805), ('Pentadact', 1804), ('amy_hennig', 1804), ('engadgetgaming', 1804), ('MaxTemkin', 1804), ('telltalegames', 1803), ('brandonnn', 1803), ('gamasutra', 1803), ('BlendoGames', 1803), ('Quinns108', 1802), ('flantz', 1802), ('leighalexander', 1801), ('avantgame', 1801), ('SupergiantGames', 1799), ('HIDEO_KOJIMA_EN', 1799), ('toucharcade', 1798), ('femfreq', 1797), ('yosp', 1797), ('notch', 1797), ('jeffgerstmann', 1797), ('GamesRadar', 1797), ('PocketGamer', 1797), ('tinybop', 1797), ('Kotaku', 1796), ('acarboni', 1796), ('UnburntWitch', 1796), ('GamesBeat', 1796), ('majornelson', 1795), ('geektreschic', 1795), ('pgbiz', 1795), ('IGN', 1794)]
#
#
# Cluster # 2
# 2360 (20%) users with valid description in this cluster
# [('Twitch', 2181), ('Xbox', 2179), ('RockstarGames', 2178), ('Ubisoft', 2175), ('GameSpot', 2164), ('PlayStation', 2164), ('PocketGamer', 2155), ('NintendoAmerica', 2148), ('IGN', 2145), ('GamesBeat', 2141), ('giantbomb', 2139), ('Polygon', 2137), ('EAMobile', 2137), ('engadgetgaming', 2136), ('SupergiantGames', 2134), ('telltalegames', 2132), ('GamesRadar', 2132), ('AppStore', 2127), ('popcap', 2114), ('Kotaku', 2113), ('GooglePlay', 2112), ('gamasutra', 2111), ('2K', 2104), ('ID_AA_Carmack', 2102), ('notch', 2101), ('TimOfLegend', 2100), ('HIDEO_KOJIMA_EN', 2089), ('Quinns108', 2081), ('fullbright', 2076), ('pgbiz', 2071), ('levine', 2063), ('WH1SKI', 2052), ('patrickklepek', 2032), ('Pentadact', 2024), ('acarboni', 2003), ('bfod', 1992), ('leighalexander', 1975), ('MaxTemkin', 1941), ('tinybop', 1235), ('TheEllenShow', 404), ('jimmyfallon', 384), ('steam_games', 382), ('brandonnn', 381), ('YouTube', 376), ('toucharcade', 368), ('tha_rami', 366), ('BarackObama', 363), ('EA', 338), ('stephentotilo', 325), ('helvetica', 315)]
#
#
# Cluster # 3
# 4940 (42%) users with valid description in this cluster
# [('BarackObama', 1593), ('elonmusk', 1468), ('NASA', 1181), ('BillGates', 1051), ('Google', 1041), ('PlayStation', 1008), ('Twitter', 1004), ('YouTube', 946), ('RockstarGames', 857), ('tim_cook', 845), ('AppStore', 822), ('WIRED', 815), ('neiltyson', 809), ('steam_games', 808), ('SpaceX', 800), ('NintendoAmerica', 761), ('Snowden', 743), ('nytimes', 733), ('Ubisoft', 721), ('Xbox', 719), ('GooglePlay', 711), ('IGN', 711), ('TechCrunch', 700), ('TheEllenShow', 698), ('instagram', 697), ('POTUS44', 689), ('verge', 682), ('HIDEO_KOJIMA_EN', 678), ('jimmyfallon', 664), ('Android', 658), ('Polygon', 649), ('tha_rami', 631), ('Medium', 621), ('notch', 618), ('ustwo', 616), ('Dropbox', 614), ('Twitch', 611), ('jk_rowling', 609), ('EmmaWatson', 601), ('realDonaldTrump', 592), ('stephenfry', 589), ('TEDTalks', 589), ('BBCBreaking', 588), ('TimOfLegend', 588), ('gamasutra', 580), ('MarsCuriosity', 578), ('RobertDowneyJr', 565), ('Kotaku', 562), ('unity3d', 554), ('NatGeo', 553)]
#
#
# Cluster # 4
# 2196 (19%) users with valid description in this cluster
# [('RockstarGames', 1703), ('Ubisoft', 1675), ('Xbox', 1673), ('PlayStation', 1673), ('chrisremo', 1670), ('IGN', 1669), ('tha_rami', 1660), ('Kotaku', 1650), ('Twitch', 1649), ('br', 1648), ('patrickklepek', 1642), ('ibogost', 1638), ('giantbomb', 1636), ('avantgame', 1635), ('helvetica', 1634), ('TimOfLegend', 1632), ('HIDEO_KOJIMA_EN', 1632), ('GameSpot', 1632), ('brandonnn', 1629), ('stephentotilo', 1626), ('engadgetgaming', 1625), ('leighalexander', 1625), ('flantz', 1622), ('kirkhamilton', 1619), ('acarboni', 1615), ('NintendoAmerica', 1614), ('notch', 1614), ('idlethumbs', 1614), ('pgbiz', 1612), ('femfreq', 1607), ('toucharcade', 1606), ('PocketGamer', 1605), ('2K', 1605), ('GamesRadar', 1603), ('Pentadact', 1603), ('fullbright', 1601), ('GooglePlay', 1598), ('gamasutra', 1594), ('SupergiantGames', 1587), ('MaxTemkin', 1582), ('EAMobile', 1580), ('WH1SKI', 1578), ('Polygon', 1573), ('Quinns108', 1570), ('bfod', 1570), ('tinybop', 1566), ('ID_AA_Carmack', 1564), ('GamesBeat', 1563), ('AppStore', 1558), ('telltalegames', 1552)]

# %% [markdown]
# Reviewing the clustering results, it is apparent that K = 3 generated to most interesting clusters. The results are (again) presented below.

# %%
# %% K-modes clustering, show top keywords in each cluster

NUM_CLUSTER = 3
N_KEYWORDS = 20
N_DESC = 0

PATH = os.path.normpath('c:\\Users\\Vincent\\Game-Revenant\\Shadows\\ustwo_sampled_friend_fol_cluster')
FILE_PREFIX = 'kmode_idlimit-75_'
FULL_PATH = os.path.join(PATH, FILE_PREFIX + str(NUM_CLUSTER) + '.csv')
results = pd.read_csv(FULL_PATH).dropna()
n_total = len(results)

for cluster in range(0, NUM_CLUSTER):
    corpus = results.loc[results['cluster'] == cluster]
    n_corpus = len(corpus)
    vocab = gen_vocab_list(corpus['friend_name'])
    print('Cluster: ' + str(cluster))
    print(str(n_corpus) + ' (' + str(round(n_corpus/n_total*100)) + '%) users with valid description in this cluster')
    print(Counter(vocab).most_common(N_KEYWORDS))
    print('\n')
# Out:
# Cluster: 0
# 4500 (41%) users with valid description in this cluster
# [('BarackObama', 1708), ('elonmusk', 1590), ('NASA', 1299), ('PlayStation', 1276), ('BillGates', 1170), ('RockstarGames', 1132), ('Twitter', 1112), ('steam_games', 1073), ('YouTube', 1072), ('Ubisoft', 998), ('NintendoAmerica', 979), ('IGN', 953), ('Xbox', 946), ('HIDEO_KOJIMA_EN', 889), ('AppStore', 886), ('Polygon', 860), ('GooglePlay', 813), ('Twitch', 791), ('Kotaku', 788), ('TheEllenShow', 769)]
#
#
# Cluster: 1
# 3149 (29%) users with valid description in this cluster
# [('chrisremo', 2928), ('tha_rami', 2924), ('br', 2910), ('stephentotilo', 2908), ('kirkhamilton', 2904), ('helvetica', 2903), ('ibogost', 2901), ('flantz', 2899), ('brandonnn', 2898), ('idlethumbs', 2883), ('avantgame', 2882), ('toucharcade', 2877), ('RockstarGames', 2875), ('amy_hennig', 2871), ('IGN', 2867), ('TimOfLegend', 2863), ('patrickklepek', 2863), ('femfreq', 2862), ('Ubisoft', 2860), ('Kotaku', 2859)]
#
#
# Cluster: 2
# 3371 (31%) users with valid description in this cluster
# [('RockstarGames', 2946), ('Ubisoft', 2928), ('Xbox', 2921), ('PlayStation', 2920), ('GameSpot', 2897), ('Twitch', 2896), ('IGN', 2892), ('NintendoAmerica', 2868), ('engadgetgaming', 2851), ('Polygon', 2850), ('GamesRadar', 2849), ('Kotaku', 2848), ('gamasutra', 2821), ('giantbomb', 2819), ('SupergiantGames', 2818), ('PocketGamer', 2812), ('telltalegames', 2811), ('HIDEO_KOJIMA_EN', 2811), ('2K', 2799), ('TimOfLegend', 2796)]

# %% [markdown]
# The overlap in the top 50 accounts between clusters was minimal, suggesting good separation.
#
# Cluster \#2 is comprised of users that are interested in mainstream gaming, as fans or consumers. Top friends include large game publishers (Rockstar Games, Ubisoft), gaming consoles (Xbox, Playstation), gaming content mediums (Twitch), and publications (IGN, Polygon).
#
# Cluster \#1 is composed of users that are interested in indie video games (i.e. smallar video game creators). The accounts listed are primarily associated with individual video game developers or creators. Consultation with a domain expert (Frank DiCola, founder/CEO of Game Revenant and lead designer of WSS) revealed that these users tend to be very active on Twitter, and will post content that is not strictly related to gaming (e.g. social issues, politics).
#
# The accounts in Cluster \#0 do not have a clear theme. A number of accounts tend to be generally popular, and have a very high number of followers (e.g. Barack Obama, Elon Musk). Another indication is that ratio between the users that follow the top accounts and the total number of users in the cluster is low (<0.5).
#
# ## Business strategy recommendations <a name='strategy'></a>
#
# The following demographics should be prioritized in ad targeting
#
#  - Video game fans and enthusiasts
#  - Video game professionals
#  - Indie game fans and professionals
#
# Facebook and Twitter differ in their ad targeting capabilities. Recommendations will be specific to what each platform offers.
#
# ### Recommendations for Facebook ads <a name='fb'></a>
#
# Facebook allows targeting based on it users' profession and interests. Facebook-specific recommendations are as follows:
# 1. **Gaming professionals**. Users can be targeted based on their profession. Based on the K-modes analysis of @ustogames follower descriptions, professionals such as game designers, graphic designers, UX designers, illustrators and other creatives should be specifically targeted.
# 2. **"Mainstream" video game fans**. Based on Cluster \#2 of the DBSCAN analysis of @ustogames follower friends, Facebook users who have expressed interest in popular gaming studios (Ubisoft, Rockstar Games), platforms (Xbox, Playstation), and media (Gamespot, Twitch) should be specifically targeted.
# 3. **Indie video game fans**. Based on clustering analysis on @ustogames follower descriptions and friends, smaller independent gaming studios, developers, and media should specifically be targted.
#
# A/B testing can be implemented to determine if any particular demographic is especially receptive to WSS advertising.
#
# ### Recommendations for Twitter ads <a name='twitter'></a>
#
# Follower targeting is available on Twitter. Twitter users similiar to the followers of a list of usernames will be targeted. From the results of the DBSCAN analysis of @ustwo follower friends, two user name lists can be generated, one for the usernames in Cluster \#1 and another for those in Cluster \#2.
#
# Follower targeting can also be performed with @ustogames and other similiar mobile premium game Twitter accounts.
#
# Finally, keyword targeting is also available on Twitter. The keywords recommended for Facebook targeting can be used similarily.
