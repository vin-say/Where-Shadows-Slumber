# %% [markdown]
# ## Motivation
#
# Proper audience targeting is a critical component of a successful advertising campaign. This notebook aims to identify customer demographics that may be particularly receptive to Game Revenant's (GR) advertising. Analysis is performed on unstructured social media data, specifically from Twitter. Compared to other social media, Twitter's API allows greater access to user data, enabling more effective data mining.
#
# GR currently has too few followers on Twitter to allow for productive data mining. However, the Twitter accounts of rival companies can be analyzed as well. *Where Shadows Slumber* (WSS) is frequently compared to *Monument Valley*, a mobile puzzle game produced by USTWO Games, by game critics and customer reviewers. As of this writing, @ustwogames has over 126k followers.
#
# Customer interests were estimated by 1) examining the profile description of @ustogames followers, and 2) examining the most popular friends among @ustogames followers. Preprocessed descriptions were examined via two clustering approches, K-modes and
# DBSCAN. In Twitter's official terminology, a 'friend' is an account a user follows. The most popular friends were clustered via K-modes. The rationale behind the unorthodox application of K-modes will be explained later in the notebook.
#
# ## Methods and Results
#
# The Twitter profiles of @ustogames were mined via the python package Tweepy and written to a SQL database (refer to *pull_data_twitter.py* and *sqlite_fx.py* for script and function codes).

# %%
# Autoreload to accomodate script updates without restarting notebook
# %load_ext autoreload
# %autoreload 2
# Move to main directory of the Customer-Segmentation project
# %cd ..
# Out:
# C:\Users\Vincent S\game-revenant\Customer-Segmentation

# %%
import pandas as pd
import sqlalchemy as sa
from pathlib import Path

DB_NAME = 'customer-segmentation'
TAB_NAME = 'ustwo_followers'

# Pull interim data from SQLite DB
e = sa.create_engine('sqlite:///./data/interim/' + DB_NAME + '.sqlite')
query = 'SELECT * FROM ' + TAB_NAME
users = pd.read_sql_query(query, e)

users.head()
# Out:
#    index                   id            id_string                name  \
# 0      0  1114109046792032256  1114109046792032256              Hiyoru
# 1      1  1120790192128954371  1120790192128954371  Tom Baines 🏳️‍🌈 🇪🇺
# 2      2            113652889            113652889     Marmalade Games
# 3      3            363116063            363116063            MIT SHAH
# 4      4            972169508            972169508        Kyrie E.H.C.
#
#       screen_name             location                      url  \
# 0         Hiyoru6                 None                     None
# 1     TomBaines16  North West, England                     None
# 2  MarmaladeGames           London, UK   http://t.co/sPUf5LShHE
# 3       mitshah97            Ahmedabad                     None
# 4        KyrieEHC          Madison, WI  https://t.co/ajE03P8x2g
#
#                                          description  protected  verified  \
# 0                          so para fotos de desenhos          0         0
# 1  Extreme sports calendar model. \nKeeping retro...          0         0
# 2                                               None          0         0
# 3                          #Unity3d #Game #Developer          0         0
# 4  Still believes in the warmth in interaction. S...          0         0
#
#    followers_count  friend_count  listed_count  favourites_count  \
# 0                1            21             0               139
# 1               29           169             0               961
# 2              506           262            13               304
# 3               39           279             1                22
# 4              333          1103            18              1118
#
#    statuses_count                      created_at  default_profile  \
# 0               5  Fri Apr 05 10:14:30 +0000 2019                1
# 1             456  Tue Apr 23 20:42:59 +0000 2019                0
# 2             471  Fri Feb 12 15:07:07 +0000 2010                0
# 3              13  Sat Aug 27 15:13:29 +0000 2011                1
# 4             734  Mon Nov 26 15:27:59 +0000 2012                0
#
#    default_profile_image
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0

# %%
print(str(len(users)) + ' @ustwogames follower profiles were mined')
# Out:
# 125925 @ustwogames follower profiles were mined

# %% [markdown]
# ### Text wrangling of profile descriptions
#
# Although a number of parameters were mined, only the profile description and identifying user id are of interest in the proceeding analysis.
#
# Prior to analysis, unstructured text data must be preprocessed. Punctuation, emojis, and excess white space were removed. All words were converted to lowercase and tokenized. Stopwords were removed. The NLTK stopword list was extended by several words that were found to be common in profile descriptions, but did not add any useful information about user interests.

# %%
import nltk
import re
import numpy as np

def normalize_doc(doc, stop_words):
    # remove special characters and white space. This filters out non-Latin languages!!
    doc = re.sub(r'[^a-zA-Z\s]', ' ', doc, re.IGNORECASE|re.ASCII)
    # remove single characters
    doc = re.sub(r'\b[a-zA-Z]\b', '', doc, re.IGNORECASE|re.ASCII)    
    # remove whitespace at beginning and end of string
    doc = doc.strip()
    # convert all characters to lowercase
    doc = doc.lower()
    # tokenize document
    tokens = nltk.word_tokenize(doc)
    # remove stop words
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # recreate doc from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc

stop_words = nltk.corpus.stopwords.words('english')
stop_words.extend(['co', 'https', 'http', 'gmail', 'com', 'like', 'love'])

users['clean_desc'] = users['description'].map(lambda doc: normalize_doc(doc, stop_words) 
                                                if doc is not None
                                                else np.nan)

users[['description','clean_desc']].head()
# Out:
#                                          description  \
# 0                          so para fotos de desenhos
# 1  Extreme sports calendar model. \nKeeping retro...
# 2                                               None
# 3                          #Unity3d #Game #Developer
# 4  Still believes in the warmth in interaction. S...
#
#                                           clean_desc
# 0                             para fotos de desenhos
# 1  extreme sports calendar model keeping retro al...
# 2                                                NaN
# 3                               unity game developer
# 4  still believes warmth interaction studied game...

# %% [markdown]
# For now, only profile descriptions in English were analyzed. Language identification of short text is challenging, and the more common language identication libraries (e.g. langid) were inaccurately classifying certain profile descriptions. Facebook's FastText library offers an alternative that has shown relatively high accuracy with short text language classification (http://alexott.blogspot.com/2017/10/evaluating-fasttexts-models-for.html).
#
# English profiles were lemmatized using the NLP libary spaCy, completing the text preprocessing stage of the analysis pipeline. Lemmatization can take several minutes, so the updated DataFrame was saved to a csv file.

# %%
import os
import fasttext
import spacy

nlp = spacy.load('en') #download 'small' version of english model

def lemmatize_doc(doc):
    doc = nlp(doc)
    doc = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in doc])
    return doc

# import and apply FastText model for language identification
idlang_path = 'data/external/fasttext_training_data/lid.176.bin'
idlang_model = fasttext.FastText.load_model(idlang_path)

users['lang_id'] = users['clean_desc'].map(lambda doc: idlang_model.predict(doc) 
                                            if doc == doc 
                                            else np.nan)

# only English profiles are lemmatized; empty profiles are also ignored
users['clean_desc_en'] = users.apply(lambda row: lemmatize_doc(row['clean_desc']) 
                                        if  row['lang_id'] == row['lang_id']
                                        and row['lang_id'][0][0] == '__label__en'
                                        and row['clean_desc'] == row['clean_desc'] 
                                        else np.nan,
                                        axis=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-4fba4de83ef8> in <module>
#       1 import os
# ----> 2 import fasttext
#       3 import spacy
#       4
#       5 nlp = spacy.load('en') #download 'small' version of english model
#
# ModuleNotFoundError: No module named 'fasttext'

# %%
# Push processed data into SQLite DB. Profiles with non-English or empty descriptions were dropped
e = sa.create_engine('sqlite:///./data/processed/' + DB_NAME + '-clean.sqlite')

cleaned_tab = TAB_NAME + '_clean'
users[['id', 'clean_desc_en']].to_sql(cleaned_tab, e)

users[['description','clean_desc','clean_desc_en']].head()
# Out:
#                                          description  \
# 0                          so para fotos de desenhos
# 1  Extreme sports calendar model. \nKeeping retro...
# 2                                               None
# 3                          #Unity3d #Game #Developer
# 4  Still believes in the warmth in interaction. S...
#
#                                           clean_desc  \
# 0                             para fotos de desenhos
# 1  extreme sports calendar model keeping retro al...
# 2                                                NaN
# 3                               unity game developer
# 4  still believes warmth interaction studied game...
#
#                                        clean_desc_en
# 0                                                NaN
# 1  extreme sport calendar model keep retro alive ...
# 2                                                NaN
# 3                               unity game developer
# 4  still believe warmth interaction study game cu...

# %% [markdown]
# ### Clustering profile descriptions
#
# After preprocessing, the profile descriptions were clustered via two approaches, K-modes and DBSCAN.
#
# #### K-modes clustering
#
# Given the short length of a typical profile, a word will typically appear no more than once within a given profile description. **It would thus be more approriate to vectorize profile descriptions as binary categorical vectors, as opposed to numeric vectors.** Profile descriptions were count vectorized as binary categorical data, where a value of *1* would indicate that a given word was present in a given profile description.
#
#
# K-means is likely the most popular approach to clustering. However, its use is limited to numerical data. The K-modes algorithim was developed as an analog to K-means for categorical data (Huang 1997, 1998). Like K-means, the K-modes algorithim requires that the number of clusters be predetermined.
#
# The kmodes Python library was used to perform K-modes clustering. No optimal number of clusters was assumed a priori. Consequently, K-modes clustering for a a range of initial cluster numbers (2 through 20) was executed.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from kmodes.kmodes import KModes

DB_NAME = 'customer-segmentation-clean'
TAB_NAME = 'ustwo_followers_clean'
NUM_CLUSTERS_RNG = 16 #upper limit of cluster range to evaluate

# Pull processed data from SQLite DB
e = sa.create_engine('sqlite:///./data/processed/' + DB_NAME + '.sqlite')

#SQL query includes a WHERE statement that filters out NA values and empty strings
query = 'SELECT id, clean_desc_en FROM ' + TAB_NAME + ' WHERE clean_desc_en != \'\''
users = pd.read_sql_query(query, e)

cv = CountVectorizer(ngram_range=(1, 2), min_df=100, max_df=1.0,
                     stop_words=stop_words, binary=True)
cat_matrix = cv.fit_transform(users['clean_desc_en'])

# Connect to DB where cluster results are to be saved
DB_RESULTS_NAME = 'customer-segmentation-cluster'
e = sa.create_engine('sqlite:///./models/' + DB_RESULTS_NAME + '.sqlite')
TAB_RESULTS_PREFIX = 'ustwo_followers_k_'

for n_clusters in range(2, NUM_CLUSTERS_RNG):
    kmod = KModes(n_clusters=n_clusters, init='Huang', random_state=42, n_jobs=-1)
    y_pred = kmod.fit_predict(cat_matrix.toarray())
    users['cluster'] = kmod.labels_
    tab_name = TAB_RESULTS_PREFIX + str(n_clusters)
    users.to_sql(tab_name, e)

# %% [markdown]
# ////maybe I don't have to list keyword functions? not really sure I need
#
# The Kmodes algorithim will force the data to be organized into the predefined number of clusters. Clusters are not guaranteed to be generated in a meaningful way.
#
# In order to gauge the distinctiveness of the clusters, a vocabulary list of the most common unigrams, bigrams, and trigrams within the profile descriptions of a given cluster are generated (*gen_vocab_list*) and ordered by freqeuncy of occurance. The degree of similiarity in the top vocabulary between two clusters is a measure of the of the distance between those clusters.

# %%
from collections import Counter

# function generates a vocab list of unigrams, bigrams, and trigrams found in the corpus of profile descriptions
def gen_vocab_list(corpus):
    unigrams = [words for doc in corpus for words in doc.split()]
    ngrams = [bigram for doc in corpus for bigram in nltk.ngrams(doc.split(), 2)]
    bigrams = [token[0] + ' ' + token[1] for token in ngrams]
    ngrams = [bigram for doc in corpus for bigram in nltk.ngrams(doc.split(), 3)]
    trigrams = [token[0] + ' ' + token[1] + ' ' + token[2] for token in ngrams]
    vocab = unigrams + bigrams + trigrams
    return vocab

# function to order keywords based on their frequency in the corpus
# the min_freq argument sets a minimum frequency for a vocabulary word to be considered a keyword
def get_freq_keywords(corpus, min_freq):
    unigrams = [words for doc in corpus for words in doc.split()]
    key_counter = Counter(unigrams).most_common()
    keywords = [key[0] for key in key_counter if key[1] >= min_freq]
    return keywords

# function to detect keywords present in a document (a profile description)
def detect_keywords(doc, keywords):
    valid_words = [word for word in doc.split() if word in keywords]
    valid_words = ' '.join(valid_words)
    if not valid_words:
        valid_words = np.nan
    return valid_words

vocab = gen_vocab_list(users['clean_desc_en'].dropna())
keywords = get_freq_keywords(users['clean_desc_en'].dropna(), 500)

users['keywords'] = users['clean_desc_en'].map(lambda doc: detect_keywords(doc, keywords) 
                                                if doc is not None 
                                                else np.nan)

# %% [markdown]
# Cluster 2

# %%
def print_cluster_results(df, col_clust, col_list, clust_rng, n_keywords=10, n_desc=5):
    '''Evaluate clustering results by printing the most popular vocab words within a cluster corpus, and the occurance of those words in the cluster corpus 
    
    param df (DataFrame): contains columns with profile features and cluster assignment
    param col_clust (str): name of column containing cluster assignment
    param col_list (str list): name of column containing corpus to be analyzed
    param clust_rng (tuple): bounds of the range of clusters to be printed. Assumes integer increments of 1. 
    param n_keywords (int): number of top vocab words to be analyzed for occurance in the corpus
    param n_desc (int): number of randomly sampled twitter profiles whose features listed in col_list are to be printed
    '''
    n_total = len(df) 
    
    for cluster in range(clust_rng[0], clust_rng[1]):
        corpus = df.loc[df[col_clust] == cluster]
        n_corpus = len(corpus)
        per_label = round(n_corpus/n_total*100) # percentage of documents assigned to the cluster label 
        vocab = gen_vocab_list(corpus[col_list[0]])
        print('Cluster # ' + str(cluster))
        print(str(n_corpus) + ' (' + str(per_label) + '%) users with valid description in this cluster')
        print(Counter(vocab).most_common(n_keywords))
        print(corpus[col_list].sample(n=n_desc))
        print('\n')

# %% [markdown]
# Rundown of ALL results

# %%
# NUM_CLUSTER = 2

DB_NAME = 'customer-segmentation-cluster'
e = sa.create_engine('sqlite:///./models/' + DB_NAME + '.sqlite')

for n_clusters in range(2, NUM_CLUSTERS_RNG):

    TAB_NAME = 'ustwo_followers_k_' + str(n_clusters)
    query = 'SELECT id, clean_desc_en, cluster FROM ' + TAB_NAME + ' WHERE clean_desc_en != \'\''
    users = pd.read_sql_query(query, e)

    print('CLUSTER K = ' + str(n_clusters))
    print('\n')
    print_cluster_results(df=users, col_clust='cluster', col_list=['clean_desc_en'], clust_rng=(0,n_clusters))
# Out:
# CLUSTER K = 2
#
#
# Cluster # 0
# 47166 (98%) users with valid description in this cluster
# [('game', 10080), ('designer', 3933), ('make', 2676), ('developer', 2441), ('design', 2342), ('gamer', 2325), ('artist', 2257), ('video', 2101), ('play', 2036), ('follow', 1895)]
#                                                                                                clean_desc_en
# 14509  home world gallifrey time lock kind waste time sharing awesomeness also work programmer dovetail game
# 16151  champlain college class game artist movie lover micro painter
# 5814   yinzer interior designer
# 10799  music sport
# 47628  web app designer developer postcapitalist veg founder code boss totallyco
#
#
# Cluster # 1
# 1058 (2%) users with valid description in this cluster
# [('creative', 1092), ('director', 335), ('creative director', 271), ('designer', 198), ('game', 189), ('design', 172), ('digital', 107), ('founder', 91), ('art', 90), ('studio', 76)]
#                                                                                        clean_desc_en
# 47870  visually motivated bloke work founding friend mediamolecule dream next gen creative gaming ps
# 10279  rocket science enthusiast discoverie invention creative flair
# 48034  freelance creative technologist
# 15937  creative strategist designer kairosmediagb
# 26718  indie game developer creative director
#
#
# CLUSTER K = 3
#
#
# Cluster # 0
# 46024 (95%) users with valid description in this cluster
# [('game', 8348), ('designer', 3980), ('make', 2450), ('design', 2390), ('developer', 2373), ('gamer', 2275), ('artist', 2210), ('follow', 1809), ('work', 1753), ('art', 1725)]
#                                                                                                                       clean_desc_en
# 4355   ceo founder loveshark social ar game prev product blippar mba lb veterinarian indian irish hybrid scottish heart view mine
# 41458  senior community manager iointeractive work hitman talk game football whatever
# 9014   founder kabutarr dialogue pvt ltd brand consultant writer director producer ex politician tolerant indian young indian idiot
# 18114  modest design agency
# 45318  make excellent mistake
#
#
# Cluster # 1
# 773 (2%) users with valid description in this cluster
# [('stuff', 816), ('game', 216), ('make', 145), ('design', 77), ('designer', 71), ('thing', 63), ('art', 60), ('work', 54), ('artist', 49), ('tweet', 49)]
#                                                                                          clean_desc_en
# 30763  minecraft stuff follow interesting game content
# 27154  videogame basketball random italian stuff
# 6807   animator illustrator fbf animation producer disney espn making stuff relate sport
# 21641  chef entreprise follow new delightful stuff cook everyday pro twitter mytopolino sign axotz kkw
# 42713  tired write ynovaneenu write pcpzwmxe help keep make stuff ypthygdz
#
#
# Cluster # 2
# 1427 (3%) users with valid description in this cluster
# [('game', 1705), ('video', 1489), ('video game', 1341), ('play', 305), ('play video', 201), ('play video game', 197), ('make', 150), ('music', 116), ('youtube', 98), ('developer', 82)]
#                                                                                                 clean_desc_en
# 40554  love draw video game youtube magic unicorn dragon fantasy magic fuck yeah
# 40508  chris hardwick weed woman video game army military techno trance rave candy sleep lazy post look stuff
# 42593  video game movie entertainment news review
# 29431  experience designer vr enthusiast video game geek
# 32242  video game entertaining level
#
#
# CLUSTER K = 4
#
#
# Cluster # 0
# 37825 (78%) users with valid description in this cluster
# [('designer', 2801), ('design', 1833), ('gamer', 1826), ('make', 1616), ('follow', 1599), ('artist', 1525), ('youtube', 1369), ('life', 1286), ('gaming', 1234), ('developer', 1212)]
#                                                                                  clean_desc_en
# 13705  instagram snapchat vine pinterest bellaofficial
# 43758  animator illustrator silly character creator cinnamon addict
# 20706  subscribe youtube pastyprince gaming
# 33391  digital agency play design technology device engage people around brand find us cib alo
# 43659  human
#
#
# Cluster # 1
# 1106 (2%) users with valid description in this cluster
# [('lover', 1153), ('game', 299), ('designer', 173), ('music', 166), ('gamer', 138), ('artist', 105), ('thing', 97), ('developer', 90), ('music lover', 89), ('enthusiast', 82)]
#                                                                                                          clean_desc_en
# 7926   zen tennis monk member advocate big brother program dbsa nami ms dog lover dodger blazer la ram seahawk fanatic
# 29331  beer lover animal advocate classical musician tweet mine mine alone
# 14129  nsfw potterhead music lover low bs tolerance gamer ps english espa old madonna trust nature movie jayvansnap
# 28683  art director motion designer avocado lover founder exquisit
# 8545   official twitt profile photo musical project thomas houston follower jesus lover word
#
#
# Cluster # 2
# 8368 (17%) users with valid description in this cluster
# [('game', 9970), ('video', 1427), ('video game', 1282), ('developer', 1125), ('make', 1063), ('designer', 1039), ('play', 1037), ('game developer', 781), ('indie', 758), ('artist', 648)]
#                                                                                                                       clean_desc_en
# 13438  small indie studio launch first game light
# 8843   artist nocode illustration comic_strip game kinda bilingual en fr profile pic gomtane
# 4073   technoprenuer techactivist found startup socialsynopsis tech startup entreprenuer hack hacker pk game dprinte opendata
# 43465  youtube account andrew play check follow ill follow back hobby game favorite youtuber thediamondminecart
# 7569   seek knowledge software developer andela kenya android hood game dev game design student fgc member rap enthuse creative hit
#
#
# Cluster # 3
# 925 (2%) users with valid description in this cluster
# [('founder', 968), ('designer', 118), ('director', 111), ('ceo', 89), ('design', 89), ('creative', 71), ('developer', 69), ('digital', 54), ('product', 52), ('founder ceo', 51)]
#                                                                                                              clean_desc_en
# 43868  creative director founder mountainsgame designer artist florence previously lead designer monument valley ustwogame
# 13759  experienced entp inventor aiki solution founder aikilab cycle archery disaster resilience mindfulness
# 46511  personal opinion alexandre leboucher agharta studio founder series rogue planet shufflepuck vr gd arkane studio
# 45016  segfault jetfault founder gojobhero currently cloverpos prev yahoo nature rock
# 44354  project manager intpd founder psychoactive et gamecraftedu former president beckerigda sip igdascholar
#
#
# CLUSTER K = 5
#
#
# Cluster # 0
# 3365 (7%) users with valid description in this cluster
# [('designer', 3469), ('graphic', 556), ('game', 489), ('graphic designer', 470), ('ux', 464), ('design', 356), ('product', 336), ('illustrator', 333), ('artist', 301), ('ui', 278)]
#                                                                                                          clean_desc_en
# 32028  let introduce name maria turk ux designer year experience check website
# 46283  freelance ui ux designer senior designer verotruesocial travel addict
# 5566   level designer secondhandgame spare time work solitarythegame episodic sci fi game indiegamedev unity
# 30525  indie game developer graphic designer music art lover funny dood
# 44580  paddyduke mastodon social product designer freeagent irishman scotland brother rach duke iamdanduke imcalledjam
#
#
# Cluster # 1
# 740 (2%) users with valid description in this cluster
# [('stuff', 782), ('game', 225), ('make', 131), ('design', 70), ('art', 58), ('thing', 56), ('video', 55), ('tweet', 45), ('music', 44), ('work', 41)]
#                                                                                                clean_desc_en
# 45232  art craft draw fan art stuff try tumblr insta yejnoh yejnoh art usually say random stuff
# 36935  random stuff video life laugh
# 3020   retweet meme art nintendo stuff switch fc
# 1489   retweet alot stuff college student artist gamer everupward cat lover imaiir art account xfallingleave
# 43964  stuff ball
#
#
# Cluster # 2
# 42667 (88%) users with valid description in this cluster
# [('game', 8452), ('make', 2319), ('gamer', 2121), ('developer', 2086), ('design', 2005), ('video', 1893), ('play', 1837), ('artist', 1833), ('follow', 1787), ('youtube', 1553)]
#                                                                                       clean_desc_en
# 14694  digital content manager tweet thing creative wellbeing socialchange loveandlight
# 1916   travel blogger photography enfocadispara contacto md nikon sony azahara technology gamer new
# 28519  enjoy squirrel watch eat froyo make quirky game qbi oaxag
# 11006  sport sport sport sport sport sport
# 26811  let guy know late mlg update notification schedule
#
#
# Cluster # 3
# 836 (2%) users with valid description in this cluster
# [('also', 856), ('game', 278), ('play', 126), ('make', 103), ('video', 87), ('youtube', 81), ('follow', 76), ('video game', 65), ('gamer', 63), ('thing', 61)]
#                                                                                          clean_desc_en
# 2863   producer check overwhelm switch steam also socketeer ps xb steam marist alumnus socaweall
# 31806  soon youtuber yet also flower flower unite
# 40675  small team dedicate create unique beautiful meaningful game also animation creator antyzthegame
# 41859  hi play video game try become voice actor also hope become history teacher enjoy life
# 10615  commander wolffe number cc th battalion general master plo koon also swrp
#
#
# Cluster # 4
# 616 (1%) users with valid description in this cluster
# [('game', 825), ('designer', 662), ('game designer', 624), ('artist', 90), ('work', 65), ('developer', 60), ('make', 55), ('founder', 43), ('writer', 42), ('programmer', 41)]
#                                                                                clean_desc_en
# 47298  independant game designer director currently make slamdoku
# 16790  gamedev indiedev pixelart game designer pixel artist call win
# 1058   creator sparkle kitty double dad game designer art monkey around round guy yqkkeii fg
# 36586  honestly tired writer game designer could use long nap
# 11507  two super nerdy tabletop game designer south philly ask us beneathnexu
#
#
# CLUSTER K = 6
#
#
# Cluster # 0
# 43812 (91%) users with valid description in this cluster
# [('game', 9153), ('designer', 3500), ('make', 2472), ('developer', 2313), ('gamer', 2217), ('artist', 2088), ('video', 1961), ('play', 1937), ('work', 1666), ('follow', 1644)]
#                                                                                                                                    clean_desc_en
# 25075  competitive cod player use code balcat purchase owttb clayster god
# 39751  founder president capy sworcery super time force ultra starve shipwreck come avatar soft rumpus beatfist
# 29432  mum mezzo soprano dame british empire rcmlondon theroyalopera lporchestra tenebraechoir amnestyuk mrjamesob auroraorchestra gloscathedral
# 3123   software engineer lularoe student lambdaschool previously controlpad thestartstudio microsoft
# 71     prince videogame nintendo playstation lover make indie game gocagame
#
#
# Cluster # 1
# 1095 (2%) users with valid description in this cluster
# [('director', 1137), ('creative', 328), ('art', 288), ('creative director', 269), ('game', 241), ('art director', 237), ('designer', 200), ('design', 173), ('founder', 139), ('digital', 86)]
#                                                                                                        clean_desc_en
# 38013  director digital development bad rutter aspire hacker
# 29629  design director giphy product designer make internet weird tech design art tech past rga droga razorfish akqa
# 6992   director
# 3994   nyc visual developer game television marketing art director avs hoboken business inquiry maggierosestudio
# 22481  creator moby flick writer actor director psn reddit twitch xxgodzilla xx
#
#
# Cluster # 2
# 2118 (4%) users with valid description in this cluster
# [('design', 2330), ('game', 639), ('designer', 338), ('art', 284), ('game design', 266), ('graphic', 229), ('ux', 221), ('product', 199), ('digital', 153), ('graphic design', 145)]
#                                                                                                                 clean_desc_en
# 22986  meet fred eric award winning london base design animation agency
# 47799  aka orla cassidy designer dancer footballer speaker ask question round nuisance design lead tapadoo
# 45211  freelance learning experience designer cath elli learn design passionate create authentic powerful learning experience
# 36516  product manager jack trade forgereply narrative design business stuff gamer dad football fan view
# 13801  course leader game design gamesdeslcc physical computing specialist base university art london
#
#
# Cluster # 3
# 163 (0%) users with valid description in this cluster
# [('day', 170), ('night', 163), ('game', 61), ('designer', 34), ('developer', 32), ('designer day', 19), ('work', 18), ('indie', 17), ('artist', 16), ('dev', 16)]
#                                                                                                                    clean_desc_en
# 13886  day journalism night medical hum phd sussexuni history creativity mental health victorianist occasional crafter view mine
# 38056  indie dev afroranger small game night senior ui developer day
# 45732  software merakivoice day produce unboxpod night hardcore manutd fan day every day
# 46290  ux researcher day unapologetic geek gamer night motivate simplify technology masse
# 30424  graphic designer day video game fisherman night
#
#
# Cluster # 4
# 485 (1%) users with valid description in this cluster
# [('hi', 487), ('game', 111), ('name', 84), ('follow', 67), ('hi name', 63), ('play', 56), ('youtube', 55), ('video', 51), ('make', 45), ('i', 43)]
#                                                                                                                   clean_desc_en
# 4192   hi idk man guess
# 9669   yetee game love beef jerky eat mythical beast working artist make hi quality affordable clothe art avatar sarahgraleyart
# 32084  hi wayside gaming video game clan clan relaxed version clan allow game pace
# 29118  hi gamerrepublic upload awesome video go show channel subscribe thank
# 4085   hi i be justin never anything say mostly retweet promote twitch stream newly make instagram zqouapgp
#
#
# Cluster # 5
# 551 (1%) users with valid description in this cluster
# [('instagram', 554), ('follow', 175), ('follow instagram', 86), ('youtube', 79), ('game', 64), ('snapchat', 61), ('facebook', 41), ('artist', 40), ('designer', 36), ('gamer', 32)]
#                                                                                                                                     clean_desc_en
# 22588  go check instagram facebook page minigunnergame
# 25613  well jello child professional talker interest horror steampunk travel anime occasionally decent artist xd instagram prickely pumpkin patch
# 46748  illustrator comic artist author rad island instagram wpl llfv patreon rjgdqcd youtube ppa zjhhqg
# 32550  year old youtuber singer pvp master instagram gb barberianyt
# 15078  amsterdam instagram arashstudio
#
#
# CLUSTER K = 7
#
#
# Cluster # 0
# 45812 (95%) users with valid description in this cluster
# [('game', 8663), ('designer', 3879), ('make', 2539), ('developer', 2378), ('gamer', 2251), ('artist', 2048), ('play', 1907), ('video', 1907), ('follow', 1778), ('design', 1736)]
#                                                               clean_desc_en
# 45650  doctor seo pay search social marketing online pr read blog saxb xboi
# 10712  love lowpoly art
# 2395   paralegal us army snap gab insta gabo
# 6700   rt
# 31954  think
#
#
# Cluster # 1
# 33 (0%) users with valid description in this cluster
# [('product', 35), ('head', 34), ('head product', 18), ('design', 8), ('ux', 7), ('father', 4), ('founder', 4), ('product design', 4), ('geek', 3), ('tweet', 3)]
#                                                                                                                                  clean_desc_en
# 6615   head product
# 45828  head product ua monetization metamoki spicyhorse superreward father black pug name maxwell bakamono txixix guitar vocal
# 12847  creative air head excellent prospect product designer organic vegetable grower slow food enthusiast undiscovere musician round good egg
# 9842   husband dad head product getimpactly avid reader learner focus create value improve little bit every day
# 45074  head product back market bass player geek mobile videogame addict
#
#
# Cluster # 2
# 222 (0%) users with valid description in this cluster
# [('game', 262), ('gaming', 245), ('video', 49), ('play', 49), ('youtube', 30), ('video game', 28), ('news', 27), ('channel', 26), ('follow', 25), ('gamer', 22)]
#                                                                                                                           clean_desc_en
# 43919  thousand gear independent game development studio barcelona develop stress taxi publish animal zombie smartphone indiedev gaming
# 47847  sr producer ad product ea opinion work game popcap thefiremonkey previously work competitive gaming fifa
# 19836  please check youtube gaming channel xke money live year old playing video game life business inquiry darkmoolah
# 15272  developer gaming entertainment online medium striving create innovative game pc handheld gaming market
# 45666  tablet game authority good ipad android window tablet game tablet impact video gaming industry
#
#
# Cluster # 3
# 1088 (2%) users with valid description in this cluster
# [('game', 1141), ('art', 746), ('design', 736), ('game design', 270), ('designer', 174), ('artist', 128), ('make', 127), ('game art', 127), ('video', 114), ('student', 102)]
#                                                                                                                     clean_desc_en
# 12587  game artist illustrator enjoy art game book comic_strip drink much tea love boof commission open reach contact monfolio se
# 551    get around pfp art sami jen character design onewadeaway
# 11329  yyc programming board indie game art work dark thing sleep top dungeon crawler inspire gauntlet other
# 21293  technical sound designer game development postgrad anno nge msg mecha retweet lot art previously heaven vault
# 40083  game web programmer vienna vivid passion art technology
#
#
# Cluster # 4
# 42 (0%) users with valid description in this cluster
# [('follow', 46), ('good', 45), ('game', 15), ('us', 8), ('one', 6), ('twitch', 6), ('follow good', 6), ('news', 5), ('follow us', 5), ('online', 4)]
#                                                                                                                    clean_desc_en
# 43210  twitch affiliated drop follow subscribe join movement become part good buy boyz fun laughter
# 44326  good game ever plz follow mlp minecraft gta
# 630    fascinate deep transformation sinner belove forgive renovation good beautiful god intj rt follow endorsement
# 27589  ascend nation gaming entertainment organization bring viewer good content possible show support subscribe follow interact
# 28284  well say simply cool love really good friendship hesitate follow
#
#
# Cluster # 5
# 918 (2%) users with valid description in this cluster
# [('live', 954), ('life', 187), ('game', 160), ('live life', 95), ('stream', 74), ('work', 67), ('play', 64), ('live stream', 58), ('make', 57), ('video', 57)]
#                                                                                                                        clean_desc_en
# 27842  live stream twitch please support twitch glaze
# 33023  gamer dj producer student around average nerd xbox live gamer tag hijisk
# 45567  live island independent consultant codeboutique
# 33193  psychologist psychoanalyst interested complex live creative people musician writing book music group would rather funny right
# 14078  northerner live greenwich game developer day blogger love cook bake travel go gig explore london rest time
#
#
# Cluster # 6
# 109 (0%) users with valid description in this cluster
# [('artist', 112), ('writer', 111), ('artist writer', 39), ('game', 26), ('writer artist', 20), ('designer', 17), ('gamer', 16), ('lover', 11), ('musician', 9), ('make', 8)]
#                                                                                                                       clean_desc_en
# 8552   writer artist avid reader former bookstore slave
# 15795  livestreamer law student consultant writer artist mother five word know hell anymore
# 5306   commission open then teammanticore writer comic artist creator oh hell donna deddrie maker weird plushie half manticore team
# 28459  artist try find entertain musician artist writer
# 8642   artist art manager player writer fantasy lover thing dragon
#
#
# CLUSTER K = 8
#
#
# Cluster # 0
# 1428 (3%) users with valid description in this cluster
# [('game', 1706), ('video', 1490), ('video game', 1341), ('play', 305), ('play video', 201), ('play video game', 197), ('make', 150), ('music', 116), ('youtube', 98), ('developer', 82)]
#                                                                                                                 clean_desc_en
# 24545  anything everything video game wander bs find truly great game player advice trailer anything gamertag vivaciouspirate
# 37122  happy video game
# 37003  founder scorestreak llc come soon play video game gamer lyfe competition play win sore loser
# 7143   color blind draw video game share favorite art film music overdramatic
# 11176  make cool thing share cool thing game video guide critique indie altgame gix sirtaptapblog chatter
#
#
# Cluster # 1
# 7183 (15%) users with valid description in this cluster
# [('game', 8563), ('developer', 1081), ('designer', 1006), ('make', 925), ('game developer', 760), ('play', 748), ('indie', 736), ('artist', 622), ('game designer', 605), ('work', 590)]
#                                                                                             clean_desc_en
# 27571  name drobli game name drobliland creator hardcore gamer developer play hard mood wbahuc hn
# 38767  indie game studio creator wobblybobby android xr eh guo
# 37533  guy enjoy game stream live twitch ever feel watch us
# 3062   game designer developer founder playinthegarden tweet may contain bad language typo talk cook time
# 15931  game cartoon picture amanita design studio chuchelchuchel botanicula kw jkyo
#
#
# Cluster # 2
# 1297 (3%) users with valid description in this cluster
# [('developer', 1333), ('web', 220), ('software', 190), ('designer', 183), ('io', 157), ('web developer', 145), ('software developer', 144), ('io developer', 98), ('end', 90), ('app', 89)]
#                                                                                                                                  clean_desc_en
# 42762  software developer musician family man skeptic period maintain gnu wget write maintain gnu teseq
# 4970   software developer former wrestler walzer dancer volleyball lover nintendo fanatic linux user part time cosplayer tweet ita eng
# 10483  ceo entertain agency onlyfanstv google developer appassistant nonprofit theworldcare cryptocurrency ccmember amazon influencer youtuber
# 27527  js ruby android developer car culture critic bubble tea enthusiast dairy free go hornet
# 9889   digital designer developer surfer graduate graphic design unilincoln
#
#
# Cluster # 3
# 1305 (3%) users with valid description in this cluster
# [('youtube', 1375), ('channel', 516), ('youtube channel', 426), ('check', 260), ('subscribe', 259), ('gaming', 215), ('video', 188), ('gamer', 174), ('follow', 157), ('check youtube', 145)]
#                                                                                                    clean_desc_en
# 24175  hello everybody official twitt curv voicey youtube channel sure subscribe daily content channel talk well
# 18361  subscribe conspiracy gaminghd youtube
# 20706  subscribe youtube pastyprince gaming
# 27687  lvl streamer content creator avid coffee drinker meme mystic someone good time twitch youtube master make
# 31129  youtube minecraft cod aw
#
#
# Cluster # 4
# 36227 (75%) users with valid description in this cluster
# [('designer', 2796), ('design', 1892), ('gamer', 1665), ('artist', 1521), ('make', 1434), ('follow', 1403), ('life', 1262), ('art', 1239), ('thing', 1128), ('work', 1093)]
#                                                                                  clean_desc_en
# 4823   production intern playstation visual art service group contemporary dancer opinion
# 19797  sevensarah
# 22701  worry nee know
# 16661  ot forever japanese english fandom translator sort fan account borntoshineesub oma ydcx
# 17881  zblj hsiom
#
#
# Cluster # 5
# 242 (1%) users with valid description in this cluster
# [('musician', 243), ('artist', 44), ('designer', 36), ('gamer', 30), ('writer', 23), ('composer', 18), ('director', 16), ('designer musician', 16), ('creative', 15), ('music', 15)]
#                                                                                                                      clean_desc_en
# 47757  musician giver taker circuit breaker sworcery sound shape reign majesty composer ost jim jimguthrie dot org
# 39219  photographer faa license remote pilot suas rating web designer dj musician history science aviation space coffee lover tech
# 15309  musician composer videogame movie portfolio website gxmrvtczrm seo
# 8244   ger eng fra yuri kind hobby artist writer musician etc mostly rage thing part time snooker hyper
# 16026  technologist musician sentignition arseniohall
#
#
# Cluster # 6
# 292 (1%) users with valid description in this cluster
# [('see', 305), ('thing', 23), ('follow', 22), ('world', 21), ('get', 19), ('guy', 18), ('come', 17), ('make', 17), ('one', 17), ('life', 17)]
#                                                               clean_desc_en
# 24351  hi alvin abnormally large skin tag wan na see
# 33553  see titanic movie titanic
# 1278   end world see
# 41348  designer illustrator writer see book zvquufrpg
# 31098  new online fps come roblox still development think fun wait till see
#
#
# Cluster # 7
# 250 (1%) users with valid description in this cluster
# [('movie', 254), ('music', 65), ('lover', 32), ('fan', 25), ('gamer', 25), ('tv', 25), ('book', 25), ('enthusiast', 23), ('art', 20), ('tech', 20)]
#                                                                                                                          clean_desc_en
# 3600   go watch scott pilgrim cornetto trilogy great movie bbtag alm mista ssbu shulk snake source art lrt art meme pfp chougokuoozaru
# 42202  passion music movie book kid
# 5750   husband father exercise specialist gamer music movie nut
# 12855  horror marketing thing movie vr horror filmmaker write dreadcentral hosting podcast horror direct qsancpvwfr
# 13260  young movie director blogger vg lover create short movie honor
#
#
# CLUSTER K = 9
#
#
# Cluster # 0
# 35017 (73%) users with valid description in this cluster
# [('gamer', 1811), ('design', 1597), ('follow', 1501), ('artist', 1360), ('youtube', 1226), ('life', 1221), ('gaming', 1185), ('developer', 1108), ('art', 1070), ('music', 1058)]
#                                                                                     clean_desc_en
# 24942  rexwal
# 34011  hello name agitatedsky gamer minecraft
# 27454  karaoke balloon
# 39601  creative director peter jackson wingnut ar formerly head weta digital mostly random musing
# 20306  look atwood soundcloud hear exclusive music atwood
#
#
# Cluster # 1
# 196 (0%) users with valid description in this cluster
# [('game', 239), ('programmer', 201), ('designer', 62), ('game programmer', 50), ('developer', 48), ('game designer', 39), ('game developer', 38), ('work', 30), ('artist', 27), ('make', 26)]
#                                                                                                 clean_desc_en
# 23306  game developer programmer extraordinaire general computer knowitall
# 5404   call fen wisper wisp fledgling game designer art hobbyist incidental programmer
# 33126  apex game entertainment guild game streamer youtuber programmer artist type content creator
# 13779  junior game programmer wolfandwood computer science northumbriauni
# 31619  game designer programmer currently pursue master game playable medium university california santa cruz
#
#
# Cluster # 2
# 2442 (5%) users with valid description in this cluster
# [('make', 2584), ('game', 1141), ('make game', 348), ('thing', 257), ('video', 182), ('designer', 180), ('youtube', 167), ('work', 154), ('stuff', 148), ('play', 144)]
#                                                                                                                       clean_desc_en
# 30362  clan twitter always personal youtube ap solar make big i be going to hater best
# 24967  make youtubw video check xxdropshotxx gamerz gamerz
# 36427  make game krillbite currently voayvodjo
# 18349  connor make music add snapchat theconnorhollon
# 46662  official twitter kevin tomczak mdtjqfld table game supervisor former crawforddem chairman make detroit age northern michigan
#
#
# Cluster # 3
# 1399 (3%) users with valid description in this cluster
# [('game', 1672), ('video', 1458), ('video game', 1341), ('play', 296), ('play video', 201), ('play video game', 197), ('music', 115), ('make', 114), ('youtube', 86), ('developer', 81)]
#                                                                                             clean_desc_en
# 2318   sound designer animation video game mexican honduran descent always look good story
# 41136  hey guy play video game mostly mincraft soon youtube follow follow back bye
# 2652   learn fun online learn platform teach kid computational thinking video game edtech code csforall
# 40271  watch twitch psn osamakiller avid weed smoker chill relax play video game stream go watch kick ass
# 47211  player video game sport fanatic avid reader admirer art
#
#
# Cluster # 4
# 49 (0%) users with valid description in this cluster
# [('go', 57), ('get', 53), ('follow', 14), ('go get', 12), ('back', 8), ('make', 7), ('game', 7), ('life', 6), ('try', 6), ('know', 5)]
#                                                                                                             clean_desc_en
# 3723   either shake cheez get go roo
# 40378  be not get snapback go back home page marjijuana please stay part snipar follow follow back
# 29301  griffin tale interactive one man show unless get well idea currently make retro rpg paracelsus go pixelart
# 24541  hey what s call duty minecraft xbox game go youtuber xbox name velo fuzion get xbox one
# 26569  ps ps dm partner ps cwagar ps cwagar willing take pic whenever get follow twitter nitoriousriderz go follow twitch
#
#
# Cluster # 5
# 120 (0%) users with valid description in this cluster
# [('hate', 125), ('love', 12), ('people', 10), ('know', 7), ('lover', 7), ('game', 7), ('thing', 7), ('stuff', 7), ('school', 6), ('friend', 6)]
#                                               clean_desc_en
# 41266  hate skip bayless follow back
# 13053  hate cheese cat robot pie building new world tinybop
# 7498   hate people free
# 20164  brittanyventi hate troll
# 22395  hate attitude
#
#
# Cluster # 6
# 3649 (8%) users with valid description in this cluster
# [('designer', 3788), ('game', 980), ('graphic', 521), ('game designer', 506), ('ux', 452), ('graphic designer', 437), ('design', 374), ('artist', 337), ('product', 325), ('illustrator', 322)]
#                                                                                                           clean_desc_en
# 1037   illustrator animator motion designer
# 4987   ixd interaction designer germany canada
# 7711   web designer
# 4319   montreal base voice actor designer always look collaborate kickstarter xofzfv wef shop pum etrsaz icon airismile
# 23635  ux designer gamification specialist technology enthusiast look new opportunity london
#
#
# Cluster # 7
# 156 (0%) users with valid description in this cluster
# [('game', 187), ('player', 161), ('game player', 26), ('developer', 24), ('play', 23), ('player game', 19), ('designer', 17), ('game developer', 16), ('make', 14), ('mobile', 12)]
#                                                                                                            clean_desc_en
# 35717  follow progamerpress fresh update esport game professional player game community create ramby
# 41456  tapinator inc ticker tapm develop publishe category lead mobile game app ios gplay amzn mm player install count
# 18045  game game player
# 15194  face narrative adventure game puzzle action mechanic player control positive negative character different chapter
# 28193  former cod player still game
#
#
# Cluster # 8
# 5196 (11%) users with valid description in this cluster
# [('game', 6036), ('developer', 819), ('play', 611), ('game developer', 608), ('indie', 573), ('indie game', 443), ('artist', 417), ('dev', 386), ('work', 382), ('studio', 369)]
#                                                                   clean_desc_en
# 28927  hobby game developer stress study german account kiteule
# 22224  game art
# 15409  user acquisition manager mobile game anti communism fighter rock climber
# 18842  food game
# 30298  playing game school suck follow follow back
#
#
# CLUSTER K = 10
#
#
# Cluster # 0
# 2377 (5%) users with valid description in this cluster
# [('developer', 2465), ('game', 1374), ('game developer', 790), ('designer', 290), ('indie', 289), ('web', 276), ('software', 252), ('io', 217), ('work', 205), ('indie game', 203)]
#                                                                                                            clean_desc_en
# 17227  professional gamer game developer wait mention also game developer oh oh okay well yeah
# 29699  game developer programmer qa game designer team emoveo khsdl
# 27305  entrepreneur retail shoe commerce web developer marketing shoe store sweden
# 19271  make great game come true senior unity developer pvp studio former programm ubisoftmobile craiova driverspeedboat
# 36267  computer engineer game developer founder cubesoftbilisim
#
#
# Cluster # 1
# 32476 (67%) users with valid description in this cluster
# [('designer', 1972), ('design', 1642), ('follow', 1388), ('make', 1377), ('youtube', 1152), ('life', 1105), ('gaming', 1094), ('art', 986), ('music', 980), ('thing', 978)]
#                                                                        clean_desc_en
# 20513  aspire team difference stumble block step stone use
# 22732  life great
# 21200  awesome
# 22288  heyo lexi honestly know say yeah hi
# 25917  sniping team create ggamer tryout dm us ps sponsor prospectgrip get use riskz
#
#
# Cluster # 2
# 7344 (15%) users with valid description in this cluster
# [('game', 8687), ('video', 1360), ('video game', 1225), ('play', 1006), ('make', 965), ('designer', 893), ('artist', 559), ('game designer', 558), ('work', 533), ('indie', 520)]
#                                                                            clean_desc_en
# 39814  develop bane game
# 38827  play rainbow game fortnitegame
# 12299  junior level designer black shamrock irish game designer programmer
# 42342  write intersection game culture old blog year tweet aaronthayer nickcumming qu
# 47352  make game xna unity opengl everything else come hand currently work chefvideogame
#
#
# Cluster # 3
# 1084 (2%) users with valid description in this cluster
# [('work', 1112), ('designer', 123), ('currently', 102), ('artist', 100), ('currently work', 83), ('design', 82), ('art', 65), ('thing', 64), ('make', 61), ('hard', 59)]
#                                                                                                        clean_desc_en
# 1232   ostmodern work company shape make evolve innovative digital product
# 45358  blog frill spill work marketing buy many clothe opinion obviously
# 46895  american arizona live sweden work ustwo malm enjoy ride
# 46252  senior engineer artanim geneva switzerland work cool full body vr graphic tech opinion
# 39047  building product try make perfect cup coffee also work early stage stealth product formerly marleyspoon fyber
#
#
# Cluster # 4
# 1787 (4%) users with valid description in this cluster
# [('gamer', 1847), ('youtube', 174), ('xbox', 150), ('play', 122), ('lover', 117), ('gaming', 102), ('youtuber', 97), ('follow', 95), ('ps', 92), ('artist', 90)]
#                                                                                                               clean_desc_en
# 30621  i be db gamer try find easy way i be play gamesi listen vocaloid watch anime
# 37316  pro gamer come hang fun meet people help charity win prize rigjme saa
# 44078  xbox gamer black op play ghost battle field need athlet take leader eliptic risin xbox gamertag eliptic star youtube
# 8241   make thing tech people ex spotify css hedgehog gamer pok mon trainer traveller twitch stream ari hedgehog
# 17906  cod many youtube gamer
#
#
# Cluster # 5
# 695 (1%) users with valid description in this cluster
# [('time', 761), ('full', 91), ('full time', 88), ('one', 73), ('part', 73), ('part time', 70), ('make', 52), ('good', 46), ('life', 40), ('day', 32)]
#                                                                                                                       clean_desc_en
# 45819  key life fall time get
# 30564  year old single daughter grandchild full time college student love collect emerald diamond ring love liz taylor michael jack
# 8991   full time gamedev student part time melancholiac incurable geek isfj
# 41708  dad joke time
# 40745  mem memory friend trend time well way connect plus use mayday life alert free login site
#
#
# Cluster # 6
# 529 (1%) users with valid description in this cluster
# [('designer', 570), ('graphic', 544), ('graphic designer', 476), ('illustrator', 98), ('game', 63), ('design', 63), ('artist', 61), ('designer illustrator', 50), ('graphic designer illustrator', 47), ('motion', 44)]
#                                                                                       clean_desc_en
# 11606  nerd good find christ graphic designer love create thing new nerdy check art site thank stop
# 38525  graphic designer dm tryna buy gfx
# 3404   graphic designer freelance illustrator gamer enthusiast spare time birb lover toulouse space
# 7788   graphic designer illustrator base somerset
# 8540   mom graphic designer creative workshop facilitator
#
#
# Cluster # 7
# 114 (0%) users with valid description in this cluster
# [('game', 145), ('review', 123), ('game review', 41), ('video', 35), ('news', 34), ('video game', 25), ('play', 16), ('us', 14), ('late', 14), ('app', 14)]
#                                                                                              clean_desc_en
# 9946   fantasy football videogame feature fpl tool opinion game review news infographic quiz top ten
# ...
# 30710  hotspotgn gamer newspaper better follow us news update game
# 18614  official dzwtoughenough twitter feed follow us get info dzwtoughenough watch june th dangenetwork
# 27893  dollar game competitive friendly clan weekly tournament monthly giveaway check us
#
#
# Cluster # 11
# 1812 (4%) users with valid description in this cluster
# [('artist', 1899), ('game', 374), ('designer', 223), ('art', 204), ('illustrator', 182), ('work', 152), ('concept', 122), ('developer', 115), ('animator', 109), ('concept artist', 108)]
#                                                                                               clean_desc_en
# 5838   technical artist halo previously giantsquidology abzugame
# 35657  business manager studio shanghai china animator artist need animation cutscence please ping
# 45503  graphic artist enjoy thing stuff yzea dyhf
# 11093  artist luch
# 6856   lead artist game konsuifighter freelance animator self publish comic artist thinair manga vtzzwpg lm
#
#
# Cluster # 12
# 512 (1%) users with valid description in this cluster
# [('name', 529), ('game', 76), ('play', 73), ('hi', 63), ('follow', 53), ('hi name', 47), ('i', 44), ('be', 44), ('i be', 44), ('hey', 41)]
#                                                                                     clean_desc_en
# 18881  year old daughter name gillian good boyfriend whole world sean albright
# 41317  name zach respect long respect
# 14175  empty nesting way christian ton fault imperfection porn plz want pix stop stupid name call
# 24884  name jeff
# 42026  go many name derive specie bird
#
#
# Cluster # 13
# 234 (0%) users with valid description in this cluster
# [('company', 241), ('game', 74), ('design', 31), ('mobile', 27), ('development', 26), ('game company', 23), ('work', 22), ('base', 18), ('service', 17), ('product', 17)]
#                                                                                                     clean_desc_en
# 36488  work technology company sell fruit
# 37100  company director
# 39350  company dedicate create fun game mobile device expertise experience produce top quality game high standard
# 12416  independent game development company london oxford follow update launch mr okada
# 36512  finnish indie game company new game pako forever io google play
#
#
# CLUSTER K = 15
#
#
# Cluster # 0
# 31234 (65%) users with valid description in this cluster
# [('gamer', 1389), ('follow', 1336), ('design', 1333), ('artist', 1226), ('make', 1157), ('developer', 1058), ('gaming', 1047), ('youtube', 1024), ('music', 917), ('work', 867)]
#                                                                                                  clean_desc_en
# 22713  go big go home
# 15443  art musician creativist drum percussion handpan design jazz musictherapy japan food matcha aromatherapy
# 45621  grab copy test reflex bf jjxglt nxyswwpizr
# 13942  non miraculous son bitch vaccinate loving
# 18095  never late enjoy cookie
#
#
# Cluster # 1
# 1453 (3%) users with valid description in this cluster
# [('life', 1529), ('game', 230), ('live', 183), ('live life', 96), ('make', 93), ('gamer', 87), ('music', 82), ('thing', 78), ('good', 67), ('enjoy', 67)]
#                                       clean_desc_en
# 14513  follow shiny thing life
# 40268  lead empty life
# 8967   try find world offer post grad seawolve life
# 40224  take life pinch salt
# 25530  bore sad life
#
#
# Cluster # 2
# 528 (1%) users with valid description in this cluster
# [('know', 560), ('game', 87), ('guy', 43), ('want', 40), ('make', 37), ('also', 37), ('thing', 36), ('follow', 35), ('let', 35), ('get', 35)]
#                                                                                                              clean_desc_en
# 35667  do not need know
# 43658  need know basis
# 1360   exilpf lzer confuse dreamer love music cat mom love tea book worry much know want grow de en
# 27677  year old gamer know online garrett hawke lol currently learn make video game next school year date beautiful nicshu
# 38078  make know across globe one hello time literally
#
#
# Cluster # 3
# 797 (2%) users with valid description in this cluster
# [('guy', 841), ('game', 189), ('hey', 156), ('hey guy', 142), ('youtube', 100), ('video', 89), ('follow', 84), ('channel', 83), ('play', 77), ('make', 76)]
#                                                                                                          clean_desc_en
# 17307  youtuber michael huffman tree guy back ground
# 23134  hey guy melon make sure follow new acount itzredmelon also follow friend jaiden make gfx itzredmelon itzbluefx
# 46628  indie game guy unity fan boy lead programm lover good food coffee dkdokj ivr
# 27073  one guy voice one character business shit email jordanpardun sub yt
# 39575  software guy startup founder vms xb big datum visualisation distribute math grid low level optimisation fua yin
#
#
# Cluster # 4
# 287 (1%) users with valid description in this cluster
# [('girl', 297), ('game', 48), ('gamer', 32), ('love', 19), ('video', 18), ('artist', 17), ('thing', 17), ('make', 15), ('world', 15), ('good', 15)]
#                                                                                         clean_desc_en
# 22763  girl enjoy video game much else every tweet something
# 37193  unapologetic purveyor fine pop music coffee book music poetry art jessica fletcher golden girl
# 25429  girl kid stuff really strongly dislike lot stuff wine really wine
# 21021  live sun rilly fuzzy feline baby girl anna
# 20202  lil ole country boy hunt fish girl
#
#
# Cluster # 5
# 1287 (3%) users with valid description in this cluster
# [('thing', 1357), ('game', 313), ('make', 243), ('designer', 139), ('design', 119), ('make thing', 114), ('lover', 85), ('work', 82), ('artist', 80), ('art', 74)]
#                                                                                               clean_desc_en
# 43636  name delme design thing make awesome
# 16410  play game thing oemsb eak psn hardcorefolife
# 29443  thing sometimes
# 44647  freelance editor graphic designer stylist cook addict workout experimenter collector beautiful thing
# 42938  thought thing non sequitur
#
#
# Cluster # 6
# 7843 (16%) users with valid description in this cluster
# [('game', 9370), ('video', 1298), ('video game', 1171), ('developer', 1109), ('designer', 1027), ('make', 963), ('play', 912), ('game developer', 770), ('indie', 733), ('artist', 642)]
#                                                                                                                  clean_desc_en
# 36308  creator shwip shwipturbothumb shwipmatch pinkslipracer group good old canadian make game i would xbox devs tweet mrbava
# 26503  yun line ace preferred usa ca go update please check sootsgo thank yell game issatrap
# 39844  year game industry work warcraft iii tft wow oddworld strange wrath etc creator bs wxxypq
# 39990  front end web ios developer game developer musician lua enthusiast jhk wzj rd work kvqhmmoj
# 9212   graphic designer app video game developer concept artist multimedia
#
#
# Cluster # 7
# 409 (1%) users with valid description in this cluster
# [('ps', 450), ('play', 85), ('xbox', 82), ('clan', 79), ('gamer', 76), ('add', 57), ('follow', 45), ('gaming', 42), ('team', 37), ('one', 36)]
#                                                                                                           clean_desc_en
# 20972  stay slothy always remember number priority look gb team ps sorry xbox
# 48136  human day indie dev night cook something steam ps hobbie slow care maya beatiful beagle almost never follow back
# 22955  hardcore gamer nerd fallout fan nut sony kid love food new youtuber play ps opi reawbow
# 37898  live gaming pc xbox one ps
# 18738  ps ogrushyy top hardpoint player free agent look top hardpoint clan
#
#
# Cluster # 8
# 2769 (6%) users with valid description in this cluster
# [('designer', 2857), ('graphic', 467), ('ux', 409), ('graphic designer', 396), ('product', 307), ('design', 284), ('illustrator', 281), ('product designer', 249), ('ui', 228), ('ux designer', 228)]
#                                     clean_desc_en
# 10713  ux designer developer
# 13111  graphic designer zvmwdbhtyz
# 36799  ui ux designer wellington nz
# 3375   designer nine five aspire gamedev rest day
# 2761   designer have good time
#
#
# Cluster # 9
# 232 (0%) users with valid description in this cluster
# [('london', 245), ('base', 54), ('design', 43), ('digital', 32), ('director', 32), ('base london', 28), ('art', 25), ('creative', 24), ('london base', 23), ('artist', 18)]
#                                                                                                          clean_desc_en
# 30120  animation director london royal college art graduate
# 10377  bafta nominate animation director concept artist base london found member line animation thelinestudio
# 38023  straight talk video gaming london random thought share
# 494    study bsc business birkbeck university london
# 21331  avid follower world electronic music world affair read esp military history dvd blu ray proud london gamesmaker
#
#
# Cluster # 10
# 192 (0%) users with valid description in this cluster
# [('youtube', 205), ('gamer', 204), ('channel', 62), ('youtube channel', 46), ('subscribe', 34), ('check', 34), ('game', 32), ('play', 31), ('youtube gamer', 26), ('gamer youtube', 23)]
#                                                                                                        clean_desc_en
# 23680  golden prodigy gamer follow us instagram golden prodigy broadcast make video youtube gta advanced warfare nba
# 31376  boy that s serious gamer youtube watcher
# 38329  youtube gamer hope become big channel jarrod game hall game check help build channel miee ypczk
# 7266   annoying hipster fragile snowflake youtube gamer idea go
# 17076  gamer youtube channel call lucas millman please subscribe taco
#
#
# Cluster # 11
# 671 (1%) users with valid description in this cluster
# [('director', 694), ('creative', 215), ('creative director', 178), ('art', 139), ('design', 114), ('art director', 108), ('founder', 88), ('digital', 44), ('writer', 41), ('design director', 38)]
#                                                                                                                     clean_desc_en
# 8787   purveyor fine bike shed debian developer ubuntu member hylang bdfl fmr board director opensourceorg sunfoundation engineer
# 43091  portrait photographer producer art director locate ny available globally
# 3387   art director day bedroom musician night maker electronic music mayonnaise express view
# 47293  publishing director someawesomeguy talkanddev organizer gamecampmunich team former indiemegabooth
# 47745  creative director bring sydney
#
#
# Cluster # 12
# 251 (1%) users with valid description in this cluster
# [('social', 262), ('medium', 125), ('social medium', 114), ('marketing', 23), ('design', 20), ('digital', 17), ('music', 17), ('manager', 16), ('tweet', 15), ('gamer', 14)]
#                                                                                                                clean_desc_en
# 24721  official twitter archeroutlaw instagram archeroutlaw email archeroutlawsclashofclan social medium manage stoker
# 34237  technology social entertainment sport club stc extend knowledge segi university
# 5190   social medium manager founder nga tika trading blogger kekyna
# 1726   uscannenbergphd health comm vr intervention hmc social anxiety python adobe suite
# 39942  founder drownedinsound social medium bbc music opinion belong former sunday time columnist indie label owner promoter
#
#
# Cluster # 13
# 98 (0%) users with valid description in this cluster
# [('passion', 98), ('music', 14), ('digital', 9), ('design', 9), ('work', 8), ('technology', 7), ('creative', 7), ('art', 6), ('freelance', 6), ('tech', 5)]
#                                                                          clean_desc_en
# 31133  stayen fleek haten jack passion music sport awesome
# 42202  passion music movie book kid
# 31597  dreamer passion
# 39403  gaming passion come watch ne brlhoa
# 16012  freelance artist hide passion sounddesign digitalmedia available freelance work
# Cluster # 14
# 173 (0%) users with valid description in this cluster
# [('would', 182), ('i', 46), ('i would', 42), ('follow', 17), ('youtube', 15), ('psn', 12), ('xbox', 12), ('join', 12), ('get', 11), ('make', 11)]
#                                                                                    clean_desc_en
# 17218  hi matt would share meme consider hit discord gigabyte
# 37823  switch sw nintendo i would tmrikac
# 386    another version vibe suicide would push button ya bowin let cuttin rage machine
# 2688   artist also food blogger steam i would
# 37108  make gaming video stuff would see stuff check youtube feel free subscribe drop like video

# %% [markdown]
# #### DBSCAN clustering
#
# DBSCAN (density-based spatial clustering of applications with noise) is a density-based clustering algorithim. Unlike K-modes, which will force each data point to be assigned to a cluster, DBSCAN will mark data in low-density regions as outliers.
#
# Descriptions were vectorized by normalized term frequency.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN

DB_NAME = 'customer-segmentation-clean'
TAB_NAME = 'ustwo_followers_clean'

# Pull processed data from SQLite DB
e = sa.create_engine('sqlite:///./data/processed/' + DB_NAME + '.sqlite')

#SQL query includes a WHERE statement that filters out NA values and empty strings
query = 'SELECT id, clean_desc_en FROM ' + TAB_NAME + ' WHERE clean_desc_en != \'\''
users = pd.read_sql_query(query, e)
N_DESC = 10
N_KEYWORDS = 10

tf = TfidfVectorizer(use_idf=False)
tf_matrix = tf.fit_transform(users['clean_desc_en']) #tf is normalized as opposed to cv

dbscan = DBSCAN(eps=1.2, min_samples=1000)

y_pred = dbscan.fit_predict(tf_matrix)
users['cluster'] = dbscan.labels_

# Push processed data into SQLite DB. Profiles with non-English or empty descriptions were dropped
DB_RESULTS_NAME = 'customer-segmentation-cluster'
TAB_RESULTS_NAME = 'ustwo_followers_dbscan'
e = sa.create_engine('sqlite:///./models/' + DB_RESULTS_NAME + '.sqlite')
users.to_sql(TAB_RESULTS_NAME, e)

print_cluster_results(df=users, col_clust='cluster', col_list=['clean_desc_en'], clust_rng=(0,n_clusters))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-1743168ee28a> in <module>
#      27 TAB_RESULTS_NAME = 'ustwo_followers_dbscan'
#      28 e = sa.create_engine('sqlite:///./models/' + DB_RESULTS_NAME + '.sqlite')
# ---> 29 users.to_sql(TAB_RESULTS_NAME, e)
#      30
#      31 print_cluster_results(df=users, col_clust='cluster', col_list=['clean_desc_en'], clust_rng=(0,n_clusters))
#
# ~\Anaconda3\envs\shadows\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\envs\shadows\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~\Anaconda3\envs\shadows\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1171                          if_exists=if_exists, index_label=index_label,
#    1172                          schema=schema, dtype=dtype)
# -> 1173         table.create()
#    1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#
# ~\Anaconda3\envs\shadows\lib\site-packages\pandas\io\sql.py in create(self)
#     573             if self.if_exists == 'fail':
#     574                 raise ValueError(
# --> 575                     "Table '{name}' already exists.".format(name=self.name))
#     576             elif self.if_exists == 'replace':
#     577                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'ustwo_followers_dbscan' already exists.

# %%
# Push processed data into SQLite DB. Profiles with non-English or empty descriptions were dropped
DB_RESULTS_NAME = 'customer-segmentation-cluster'
TAB_RESULTS_NAME = 'ustwo_followers_dbscan'
e = sa.create_engine('sqlite:///./models/' + DB_RESULTS_NAME + '.sqlite')
users.to_sql(TAB_RESULTS_NAME, e, if_exists='replace')

n_clusters = len(np.unique(dbscan.labels_))
clust_rng = (-1, n_clusters-1) # offset by -1 since DBSCAN's first cluster is #-1
print_cluster_results(df=users, col_clust='cluster', col_list=['clean_desc_en'], clust_rng=clust_rng)
# Out:
# Cluster # -1
# 14653 (30%) users with valid description in this cluster
# [('world', 391), ('founder', 381), ('work', 380), ('tweet', 337), ('get', 328), ('new', 327), ('fan', 316), ('tech', 315), ('team', 303), ('good', 299)]
#                                                                                                                            clean_desc_en
# 21616  serve joseph kalamaraki real fm radio show playlist since early
# 25161  fire xxevilsnipexx
# 45334  digital life home automation geek software dev pro eu fervent european xfgysmh remain supporter eu citizen stopbrexit peoplesvote
# 36638  cheap skin
# 24631  use work ea try help madden community software coin cash generator player dm detail
#
#
# Cluster # 0
# 33571 (70%) users with valid description in this cluster
# [('game', 10230), ('designer', 4115), ('make', 2613), ('developer', 2461), ('design', 2353), ('gamer', 2216), ('artist', 2185), ('video', 2092), ('play', 1971), ('follow', 1763)]
#                                                                                                                     clean_desc_en
# 9380   puzzle arcade game pc mac linux mobile steam itch io google play apple store chronobitstudio
# 7256   film tv star war superhero kwwuber keep date late tv cinema news
# 81     claudia art know use site wrong sorry
# 21051  newly conceive indie studio run jonochatt imagine create mobile game playstate come play
# 6314   software developer retro gaming sne arcade modern switch xbox one rock indie music sci fi mufc day job stuff see tapmantwo

# %%
users = pd.read_csv('preprocess_ustwo_users.csv')

len(users['clean_desc_en'].dropna())

# %%
len(np.unique(dbscan.labels_))
# Out:
# 2

# %%
DB_NAME = 'customer-segmentation'
TAB_NAME = 'ustwo_followers'

# %%
import pandas as pd
import nltk
import re
import numpy as np
import os
import fasttext
import spacy

# %%
# %% K-modes clustering, show top keywords in each cluster

NUM_CLUSTER = 3
N_KEYWORDS = 50
N_DESC = 0

PATH = os.path.normpath('c:\\Users\\Vincent\\Game-Revenant\\Shadows\\ustwo_sampled_friend_fol_cluster')
FILE_PREFIX = 'kmode_idlimit-75_'
FULL_PATH = os.path.join(PATH, FILE_PREFIX + str(NUM_CLUSTER) + '.csv')
results = pd.read_csv(FULL_PATH).dropna()
n_total = len(results)

for cluster in range(0, NUM_CLUSTER):
    corpus = results.loc[results['cluster'] == cluster]
    n_corpus = len(corpus)
    vocab = gen_vocab_list(corpus['friend_name'])
    print('Cluster: ' + str(cluster))
    print(str(n_corpus) + ' (' + str(round(n_corpus/n_total*100)) + '%) users with valid description in this cluster')
    print(Counter(vocab).most_common(N_KEYWORDS))
#    print(corpus[['description','keywords']].sample(n=N_DESC))
    print('\n')
# Out:
# Cluster: 0
# 4500 (41%) users with valid description in this cluster
# [('BarackObama', 1708), ('elonmusk', 1590), ('NASA', 1299), ('PlayStation', 1276), ('BillGates', 1170), ('RockstarGames', 1132), ('Twitter', 1112), ('steam_games', 1073), ('YouTube', 1072), ('Ubisoft', 998), ('NintendoAmerica', 979), ('IGN', 953), ('Xbox', 946), ('HIDEO_KOJIMA_EN', 889), ('AppStore', 886), ('Polygon', 860), ('GooglePlay', 813), ('Twitch', 791), ('Kotaku', 788), ('TheEllenShow', 769), ('gamasutra', 758), ('tha_rami', 749), ('jimmyfallon', 735), ('TimOfLegend', 725), ('notch', 718), ('GameSpot', 671), ('SupergiantGames', 654), ('ID_AA_Carmack', 633), ('telltalegames', 601), ('bethesda', 501), ('2K', 491), ('femfreq', 427), ('PocketGamer', 408), ('engadgetgaming', 397), ('toucharcade', 385), ('helvetica', 377), ('GamesRadar', 368), ('fullbright', 367), ('bfod', 349), ('leighalexander', 345), ('majornelson', 344), ('levine', 342), ('CallofDuty', 341), ('popcap', 327), ('br', 318), ('brandonnn', 315), ('chrisremo', 310), ('EAMobile', 308), ('Pentadact', 306), ('yosp', 290)]
#
#
# Cluster: 1
# 3149 (29%) users with valid description in this cluster
# [('chrisremo', 2928), ('tha_rami', 2924), ('br', 2910), ('stephentotilo', 2908), ('kirkhamilton', 2904), ('helvetica', 2903), ('ibogost', 2901), ('flantz', 2899), ('brandonnn', 2898), ('idlethumbs', 2883), ('avantgame', 2882), ('toucharcade', 2877), ('RockstarGames', 2875), ('amy_hennig', 2871), ('IGN', 2867), ('TimOfLegend', 2863), ('patrickklepek', 2863), ('femfreq', 2862), ('Ubisoft', 2860), ('Kotaku', 2859), ('BlendoGames', 2858), ('fullbright', 2857), ('PlayStation', 2851), ('giantbomb', 2848), ('engadgetgaming', 2845), ('notch', 2842), ('HIDEO_KOJIMA_EN', 2840), ('Xbox', 2840), ('WH1SKI', 2839), ('gamasutra', 2833), ('GameSpot', 2833), ('Pentadact', 2832), ('geektreschic', 2830), ('SupergiantGames', 2829), ('acarboni', 2826), ('Twitch', 2825), ('leighalexander', 2824), ('thisgame', 2824), ('telltalegames', 2819), ('Polygon', 2815), ('ID_AA_Carmack', 2815), ('PocketGamer', 2815), ('2K', 2812), ('NintendoAmerica', 2811), ('GamesRadar', 2807), ('pgbiz', 2803), ('GamesBeat', 2801), ('bfod', 2796), ('MaxTemkin', 2794), ('levine', 2792)]
#
#
# Cluster: 2
# 3371 (31%) users with valid description in this cluster
# [('RockstarGames', 2946), ('Ubisoft', 2928), ('Xbox', 2921), ('PlayStation', 2920), ('GameSpot', 2897), ('Twitch', 2896), ('IGN', 2892), ('NintendoAmerica', 2868), ('engadgetgaming', 2851), ('Polygon', 2850), ('GamesRadar', 2849), ('Kotaku', 2848), ('gamasutra', 2821), ('giantbomb', 2819), ('SupergiantGames', 2818), ('PocketGamer', 2812), ('telltalegames', 2811), ('HIDEO_KOJIMA_EN', 2811), ('2K', 2799), ('TimOfLegend', 2796), ('EAMobile', 2796), ('AppStore', 2780), ('GooglePlay', 2774), ('notch', 2769), ('GamesBeat', 2758), ('ID_AA_Carmack', 2755), ('pgbiz', 2727), ('popcap', 2720), ('Quinns108', 2693), ('patrickklepek', 2690), ('fullbright', 2687), ('levine', 2679), ('Pentadact', 2639), ('leighalexander', 2627), ('bfod', 2617), ('acarboni', 2617), ('WH1SKI', 2616), ('MaxTemkin', 2537), ('tinybop', 1846), ('tha_rami', 996), ('brandonnn', 946), ('toucharcade', 943), ('chrisremo', 906), ('br', 903), ('stephentotilo', 899), ('helvetica', 883), ('ibogost', 883), ('femfreq', 873), ('kirkhamilton', 844), ('avantgame', 840)]

# %%
FULL_PATH = os.path.normpath('c:\\Users\\Vincent\\Game-Revenant\\Customer-Segmentation\\ustwo_sampled_friend_fol_cluster')
FILE_PREFIX = 'kmode_idlimit-' + str(ID_LIMIT) + '_'

cv = CountVectorizer(min_df=1, max_df=1.0, binary=True)
cat_matrix = cv.fit_transform(friends_feat['friend_name'])

NUM_CLUSTERS_RNG = 20

for n_clusters in range(2, NUM_CLUSTERS_RNG):
    kmod = KModes(n_clusters=n_clusters, init='Huang', random_state=42, n_jobs=-1)
    y_pred = kmod.fit_predict(cat_matrix.toarray()) #or cv_matrix or cos_sim_feat
#    results = pd.DataFrame({'id':desc_valid['cluster':kmod.labels_, 'description':desc_valid['clean_desc_en']})
    friends_feat['cluster'] = kmod.labels_
    filename = FILE_PREFIX + str(n_clusters) + '.csv'
    save_loc = os.path.join(FULL_PATH, filename)
    friends_feat.to_csv(save_loc, index=False)
    print('processed cluster #' + str(n_clusters))

# %%
# %% USTWO game cluster friends K-modes clustering

def id_to_name(doc, profiles):
    tokens = doc.split()
#    names = [profiles[profiles['id']==int(id_token)]['name'].item() + '(' +
#             profiles[profiles['id']==int(id_token)]['screen_name'].item() + 
#             ')' for id_token in tokens]
    names = [profiles[profiles['id']==int(id_token)]['screen_name'].item() for id_token in tokens]    
    translated_doc = ' '.join(names)
    return translated_doc


# Generate list of user profiles of interest in clustering (ordered by popularity)
ID_LIMIT = 75
top_friends = pd.read_csv('ustwo_sampled_fol_friends.csv')
top_friends = top_friends.sort_values(by='popularity_count', ascending=False)
top_friends = top_friends.iloc[1:ID_LIMIT] #start at index=1 to skip USTWO account (everyone follows)

# Check follower's friend ids against the collection above 
friends = pd.read_csv('ustwo_sampled_friends_ids.csv').drop_duplicates()
friends['is_top_friend'] = friends['friend_id'].isin(top_friends['id'])

# Convert ids to strings. 'friend_name' is a string listing all a user's top friends
friends_select = friends[friends['is_top_friend']==True][['user_id', 'friend_id']]
friends_select['friend_id'] = friends_select['friend_id'].astype(str)
friends_feat = friends_select.groupby(by='user_id')['friend_id'].apply(' '.join).reset_index()
friends_feat['friend_name'] = friends_feat['friend_id'].map(lambda doc: id_to_name(doc, top_friends))

#=============================================

FULL_PATH = os.path.normpath('c:\\Users\\Vincent\\Game-Revenant\\Shadows\\ustwo_sampled_friend_fol_cluster')
FILE_PREFIX = 'kmode_idlimit-' + str(ID_LIMIT) + '_'

cv = CountVectorizer(min_df=1, max_df=1.0, binary=True)
cat_matrix = cv.fit_transform(friends_feat['friend_name'])

NUM_CLUSTERS_RNG = 20

for n_clusters in range(2, NUM_CLUSTERS_RNG):
    kmod = KModes(n_clusters=n_clusters, init='Huang', random_state=42, n_jobs=-1)
    y_pred = kmod.fit_predict(cat_matrix.toarray()) #or cv_matrix or cos_sim_feat
#    results = pd.DataFrame({'id':desc_valid['cluster':kmod.labels_, 'description':desc_valid['clean_desc_en']})
    friends_feat['cluster'] = kmod.labels_
    filename = FILE_PREFIX + str(n_clusters) + '.csv'
    save_loc = os.path.join(FULL_PATH, filename)
    friends_feat.to_csv(save_loc, index=False)
    print('processed cluster #' + str(n_clusters))
          
          
# %% K-modes clustering, show top keywords in each cluster

NUM_CLUSTER = 3
N_KEYWORDS = 50
N_DESC = 0

PATH = os.path.normpath('c:\\Users\\Vincent\\Game-Revenant\\Shadows\\ustwo_sampled_friend_fol_cluster')
FILE_PREFIX = 'kmode_idlimit-75_'
FULL_PATH = os.path.join(PATH, FILE_PREFIX + str(NUM_CLUSTER) + '.csv')
results = pd.read_csv(FULL_PATH).dropna()
n_total = len(results)

for cluster in range(0, NUM_CLUSTER):
    corpus = results.loc[results['cluster'] == cluster]
    n_corpus = len(corpus)
    vocab = gen_vocab_list(corpus['friend_name'])
    print('Cluster: ' + str(cluster))
    print(str(n_corpus) + ' (' + str(round(n_corpus/n_total*100)) + '%) users with valid description in this cluster')
    print(Counter(vocab).most_common(N_KEYWORDS))
#    print(corpus[['description','keywords']].sample(n=N_DESC))
    print('\n')
    
   
# # %% 
# results = results.rename(columns={'cluster':'cluster_friends', 'user_id':'id'}) 

# df = pd.merge(sampled_users, results, on='id')

# CLUSTER_FRIEND = 2
# vocab = gen_vocab_list(df[df['cluster_friends']==CLUSTER_FRIEND]['clean_desc_en'].dropna())
# print(Counter(vocab).most_common(20))
